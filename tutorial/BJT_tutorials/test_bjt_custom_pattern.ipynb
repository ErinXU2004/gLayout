# %% [markdown]
# # Custom patter for routing in BJTs

# %%
# %load_ext autoreload
# %autoreload 2

# %%
from glayout.primitives.bjt import draw_bjt
from glayout import MappedPDK, sky130 , gf180
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>

# %%
pdk=gf180
pdk.activate()
# Out:
# 2025-09-08 05:46:58.234 | INFO     | gdsfactory.pdk:activate:337 - 'gf180' PDK is now active

# %%
from glayout.primitives.bjt import multiplier, __mult_array_macro

# %%
bjt=__mult_array_macro(pdk=pdk,active_area=(5,5),bjt_type="pnp",bc_rmult=2,
                       multipliers=3,
                       pattern=["A","B","B"], is_bc_shared=True)

# %%
bjt.show()
# Out:
# /headless/conda-env/miniconda3/envs/GLdev/lib/python3.10/site-packages/gdsfactory/show.py:40: UserWarning: Unnamed cells, 1 in 'Unnamed_d7139cd8$1'
#   gdspath = component.write_gds(
# 2025-09-08 05:52:51.785 | INFO     | gdsfactory.klive:show:55 - Message from klive: {"version": "0.3.3", "klayout_version": "0.30.2", "type": "open", "file": "/tmp/gdsfactory/Unnamed_d7139cd8$1.gds"}

# %%
bjt.pprint_ports()
# Out:
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━┳━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━┳━━━━━━━━━━┳━━━━━━━━━━━━┓
# ┃ name                                         ┃ width ┃ center             ┃ orientation ┃ layer    ┃ port_type  ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━╇━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━╇━━━━━━━━━━╇━━━━━━━━━━━━┩
# │ multiplier_0_C_metal_S_W                     │ 0.42  │ [-3.98, -12.495]   │ 180.0       │ [34, 0]  │ electrical │
# │ multiplier_0_contacts_c_contacts_S_row0_col… │ 0.22  │ [-3.165, -12.495]  │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_contacts_c_contacts_S_row0_col… │ 0.22  │ [-2.695, -12.495]  │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_contacts_c_contacts_S_row0_col… │ 0.22  │ [-2.225, -12.495]  │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_contacts_c_contacts_S_row0_col… │ 0.22  │ [-1.755, -12.495]  │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_contacts_c_contacts_S_row0_col… │ 0.22  │ [-1.285, -12.495]  │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_contacts_c_contacts_S_row0_col… │ 0.22  │ [-0.815, -12.495]  │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_contacts_c_contacts_S_row0_col… │ 0.22  │ [-0.345, -12.495]  │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_contacts_c_contacts_S_row0_col… │ 0.22  │ [0.125, -12.495]   │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_contacts_c_contacts_S_row0_col… │ 0.22  │ [0.595, -12.495]   │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_contacts_c_contacts_S_row0_col… │ 0.22  │ [1.065, -12.495]   │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_contacts_c_contacts_S_row0_col… │ 0.22  │ [1.535, -12.495]   │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_contacts_c_contacts_S_row0_col… │ 0.22  │ [2.005, -12.495]   │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_contacts_c_contacts_S_row0_col… │ 0.22  │ [2.475, -12.495]   │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_contacts_c_contacts_S_row0_col… │ 0.22  │ [2.945, -12.495]   │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_L_C_metal_S_W             │ 0.42  │ [-12.66, -12.495]  │ 180.0       │ [34, 0]  │ electrical │
# │ multiplier_0_dummy_L_contacts_c_contacts_S_… │ 0.22  │ [-11.845, -12.495] │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_L_contacts_c_contacts_S_… │ 0.22  │ [-11.375, -12.495] │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_L_contacts_c_contacts_S_… │ 0.22  │ [-10.905, -12.495] │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_L_contacts_c_contacts_S_… │ 0.22  │ [-10.435, -12.495] │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_L_contacts_c_contacts_S_… │ 0.22  │ [-9.965, -12.495]  │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_L_contacts_c_contacts_S_… │ 0.22  │ [-9.495, -12.495]  │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_L_contacts_c_contacts_S_… │ 0.22  │ [-9.025, -12.495]  │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_L_contacts_c_contacts_S_… │ 0.22  │ [-8.555, -12.495]  │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_L_contacts_c_contacts_S_… │ 0.22  │ [-8.085, -12.495]  │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_L_contacts_c_contacts_S_… │ 0.22  │ [-7.615, -12.495]  │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_L_contacts_c_contacts_S_… │ 0.22  │ [-7.145, -12.495]  │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_L_contacts_c_contacts_S_… │ 0.22  │ [-6.675, -12.495]  │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_L_contacts_c_contacts_S_… │ 0.22  │ [-6.205, -12.495]  │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_L_contacts_c_contacts_S_… │ 0.22  │ [-5.735, -12.495]  │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_R_C_metal_S_W             │ 0.42  │ [4.7, -12.495]     │ 180.0       │ [34, 0]  │ electrical │
# │ multiplier_0_dummy_R_contacts_c_contacts_S_… │ 0.22  │ [5.515, -12.495]   │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_R_contacts_c_contacts_S_… │ 0.22  │ [5.985, -12.495]   │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_R_contacts_c_contacts_S_… │ 0.22  │ [6.455, -12.495]   │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_R_contacts_c_contacts_S_… │ 0.22  │ [6.925, -12.495]   │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_R_contacts_c_contacts_S_… │ 0.22  │ [7.395, -12.495]   │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_R_contacts_c_contacts_S_… │ 0.22  │ [7.865, -12.495]   │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_R_contacts_c_contacts_S_… │ 0.22  │ [8.335, -12.495]   │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_R_contacts_c_contacts_S_… │ 0.22  │ [8.805, -12.495]   │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_R_contacts_c_contacts_S_… │ 0.22  │ [9.275, -12.495]   │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_R_contacts_c_contacts_S_… │ 0.22  │ [9.745, -12.495]   │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_R_contacts_c_contacts_S_… │ 0.22  │ [10.215, -12.495]  │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_R_contacts_c_contacts_S_… │ 0.22  │ [10.685, -12.495]  │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_R_contacts_c_contacts_S_… │ 0.22  │ [11.155, -12.495]  │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_R_contacts_c_contacts_S_… │ 0.22  │ [11.625, -12.495]  │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_contacts_c_contacts_E_row0_col… │ 0.22  │ [3.66, -12.485]    │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_contacts_c_contacts_W_row0_col… │ 0.22  │ [-3.88, -12.485]   │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_L_contacts_c_contacts_E_… │ 0.22  │ [-5.02, -12.485]   │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_L_contacts_c_contacts_W_… │ 0.22  │ [-12.56, -12.485]  │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_R_contacts_c_contacts_E_… │ 0.22  │ [12.34, -12.485]   │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_R_contacts_c_contacts_W_… │ 0.22  │ [4.8, -12.485]     │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_collector_W                     │ 1.0   │ [-4.02, -12.455]   │ 180.0       │ [36, 0]  │ electrical │
# │ multiplier_0_contacts_c_contacts_E_row1_col… │ 0.22  │ [3.66, -12.015]    │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_contacts_c_contacts_W_row1_col… │ 0.22  │ [-3.88, -12.015]   │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_L_contacts_c_contacts_E_… │ 0.22  │ [-5.02, -12.015]   │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_L_contacts_c_contacts_W_… │ 0.22  │ [-12.56, -12.015]  │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_R_contacts_c_contacts_E_… │ 0.22  │ [12.34, -12.015]   │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_R_contacts_c_contacts_W_… │ 0.22  │ [4.8, -12.015]     │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_B_metal_S_W                     │ 0.42  │ [-3.24, -11.755]   │ 180.0       │ [34, 0]  │ electrical │
# │ multiplier_0_contacts_b_contacts_S_row0_col… │ 0.22  │ [-2.46, -11.755]   │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_contacts_b_contacts_S_row0_col… │ 0.22  │ [-1.99, -11.755]   │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_contacts_b_contacts_S_row0_col… │ 0.22  │ [-1.52, -11.755]   │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_contacts_b_contacts_S_row0_col… │ 0.22  │ [-1.05, -11.755]   │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_contacts_b_contacts_S_row0_col… │ 0.22  │ [-0.58, -11.755]   │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_contacts_b_contacts_S_row0_col… │ 0.22  │ [-0.11, -11.755]   │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_contacts_b_contacts_S_row0_col… │ 0.22  │ [0.36, -11.755]    │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_contacts_b_contacts_S_row0_col… │ 0.22  │ [0.83, -11.755]    │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_contacts_b_contacts_S_row0_col… │ 0.22  │ [1.3, -11.755]     │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_contacts_b_contacts_S_row0_col… │ 0.22  │ [1.77, -11.755]    │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_contacts_b_contacts_S_row0_col… │ 0.22  │ [2.24, -11.755]    │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_L_B_metal_S_W             │ 0.42  │ [-11.92, -11.755]  │ 180.0       │ [34, 0]  │ electrical │
# │ multiplier_0_dummy_L_contacts_b_contacts_S_… │ 0.22  │ [-11.14, -11.755]  │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_L_contacts_b_contacts_S_… │ 0.22  │ [-10.67, -11.755]  │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_L_contacts_b_contacts_S_… │ 0.22  │ [-10.2, -11.755]   │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_L_contacts_b_contacts_S_… │ 0.22  │ [-9.73, -11.755]   │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_L_contacts_b_contacts_S_… │ 0.22  │ [-9.26, -11.755]   │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_L_contacts_b_contacts_S_… │ 0.22  │ [-8.79, -11.755]   │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_L_contacts_b_contacts_S_… │ 0.22  │ [-8.32, -11.755]   │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_L_contacts_b_contacts_S_… │ 0.22  │ [-7.85, -11.755]   │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_L_contacts_b_contacts_S_… │ 0.22  │ [-7.38, -11.755]   │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_L_contacts_b_contacts_S_… │ 0.22  │ [-6.91, -11.755]   │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_L_contacts_b_contacts_S_… │ 0.22  │ [-6.44, -11.755]   │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_R_B_metal_S_W             │ 0.42  │ [5.44, -11.755]    │ 180.0       │ [34, 0]  │ electrical │
# │ multiplier_0_dummy_R_contacts_b_contacts_S_… │ 0.22  │ [6.22, -11.755]    │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_R_contacts_b_contacts_S_… │ 0.22  │ [6.69, -11.755]    │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_R_contacts_b_contacts_S_… │ 0.22  │ [7.16, -11.755]    │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_R_contacts_b_contacts_S_… │ 0.22  │ [7.63, -11.755]    │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_R_contacts_b_contacts_S_… │ 0.22  │ [8.1, -11.755]     │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_R_contacts_b_contacts_S_… │ 0.22  │ [8.57, -11.755]    │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_R_contacts_b_contacts_S_… │ 0.22  │ [9.04, -11.755]    │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_R_contacts_b_contacts_S_… │ 0.22  │ [9.51, -11.755]    │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_R_contacts_b_contacts_S_… │ 0.22  │ [9.98, -11.755]    │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_R_contacts_b_contacts_S_… │ 0.22  │ [10.45, -11.755]   │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_R_contacts_b_contacts_S_… │ 0.22  │ [10.92, -11.755]   │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_contacts_b_contacts_E_row0_col… │ 0.22  │ [2.92, -11.545]    │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_contacts_b_contacts_W_row0_col… │ 0.22  │ [-3.14, -11.545]   │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_contacts_c_contacts_E_row2_col… │ 0.22  │ [3.66, -11.545]    │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_contacts_c_contacts_W_row2_col… │ 0.22  │ [-3.88, -11.545]   │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_L_contacts_b_contacts_E_… │ 0.22  │ [-5.76, -11.545]   │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_L_contacts_b_contacts_W_… │ 0.22  │ [-11.82, -11.545]  │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_L_contacts_c_contacts_E_… │ 0.22  │ [-5.02, -11.545]   │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_L_contacts_c_contacts_W_… │ 0.22  │ [-12.56, -11.545]  │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_R_contacts_b_contacts_E_… │ 0.22  │ [11.6, -11.545]    │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_R_contacts_b_contacts_W_… │ 0.22  │ [5.54, -11.545]    │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_R_contacts_c_contacts_E_… │ 0.22  │ [12.34, -11.545]   │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_R_contacts_c_contacts_W_… │ 0.22  │ [4.8, -11.545]     │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_contacts_b_contacts_E_row1_col… │ 0.22  │ [2.92, -11.075]    │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_contacts_b_contacts_W_row1_col… │ 0.22  │ [-3.14, -11.075]   │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_contacts_c_contacts_E_row3_col… │ 0.22  │ [3.66, -11.075]    │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_contacts_c_contacts_W_row3_col… │ 0.22  │ [-3.88, -11.075]   │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_L_contacts_b_contacts_E_… │ 0.22  │ [-5.76, -11.075]   │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_L_contacts_b_contacts_W_… │ 0.22  │ [-11.82, -11.075]  │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_L_contacts_c_contacts_E_… │ 0.22  │ [-5.02, -11.075]   │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_L_contacts_c_contacts_W_… │ 0.22  │ [-12.56, -11.075]  │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_R_contacts_b_contacts_E_… │ 0.22  │ [11.6, -11.075]    │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_R_contacts_b_contacts_W_… │ 0.22  │ [5.54, -11.075]    │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_R_contacts_c_contacts_E_… │ 0.22  │ [12.34, -11.075]   │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_R_contacts_c_contacts_W_… │ 0.22  │ [4.8, -11.075]     │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_contacts_e_row0_col0_W          │ 0.22  │ [-2.36, -10.975]   │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_contacts_e_row0_col1_W          │ 0.22  │ [-1.86, -10.975]   │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_contacts_e_row0_col2_W          │ 0.22  │ [-1.36, -10.975]   │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_contacts_e_row0_col3_W          │ 0.22  │ [-0.86, -10.975]   │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_contacts_e_row0_col4_W          │ 0.22  │ [-0.36, -10.975]   │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_contacts_e_row0_col5_W          │ 0.22  │ [0.14, -10.975]    │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_contacts_e_row0_col6_W          │ 0.22  │ [0.64, -10.975]    │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_contacts_e_row0_col7_W          │ 0.22  │ [1.14, -10.975]    │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_contacts_e_row0_col8_W          │ 0.22  │ [1.64, -10.975]    │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_contacts_e_row0_col9_W          │ 0.22  │ [2.14, -10.975]    │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_L_contacts_e_row0_col0_W  │ 0.22  │ [-11.04, -10.975]  │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_L_contacts_e_row0_col1_W  │ 0.22  │ [-10.54, -10.975]  │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_L_contacts_e_row0_col2_W  │ 0.22  │ [-10.04, -10.975]  │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_L_contacts_e_row0_col3_W  │ 0.22  │ [-9.54, -10.975]   │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_L_contacts_e_row0_col4_W  │ 0.22  │ [-9.04, -10.975]   │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_L_contacts_e_row0_col5_W  │ 0.22  │ [-8.54, -10.975]   │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_L_contacts_e_row0_col6_W  │ 0.22  │ [-8.04, -10.975]   │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_L_contacts_e_row0_col7_W  │ 0.22  │ [-7.54, -10.975]   │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_L_contacts_e_row0_col8_W  │ 0.22  │ [-7.04, -10.975]   │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_L_contacts_e_row0_col9_W  │ 0.22  │ [-6.54, -10.975]   │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_R_contacts_e_row0_col0_W  │ 0.22  │ [6.32, -10.975]    │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_R_contacts_e_row0_col1_W  │ 0.22  │ [6.82, -10.975]    │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_R_contacts_e_row0_col2_W  │ 0.22  │ [7.32, -10.975]    │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_R_contacts_e_row0_col3_W  │ 0.22  │ [7.82, -10.975]    │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_R_contacts_e_row0_col4_W  │ 0.22  │ [8.32, -10.975]    │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_R_contacts_e_row0_col5_W  │ 0.22  │ [8.82, -10.975]    │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_R_contacts_e_row0_col6_W  │ 0.22  │ [9.32, -10.975]    │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_R_contacts_e_row0_col7_W  │ 0.22  │ [9.82, -10.975]    │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_R_contacts_e_row0_col8_W  │ 0.22  │ [10.32, -10.975]   │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_R_contacts_e_row0_col9_W  │ 0.22  │ [10.82, -10.975]   │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_contacts_b_contacts_E_row2_col… │ 0.22  │ [2.92, -10.605]    │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_contacts_b_contacts_W_row2_col… │ 0.22  │ [-3.14, -10.605]   │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_contacts_c_contacts_E_row4_col… │ 0.22  │ [3.66, -10.605]    │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_contacts_c_contacts_W_row4_col… │ 0.22  │ [-3.88, -10.605]   │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_L_contacts_b_contacts_E_… │ 0.22  │ [-5.76, -10.605]   │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_L_contacts_b_contacts_W_… │ 0.22  │ [-11.82, -10.605]  │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_L_contacts_c_contacts_E_… │ 0.22  │ [-5.02, -10.605]   │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_L_contacts_c_contacts_W_… │ 0.22  │ [-12.56, -10.605]  │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_R_contacts_b_contacts_E_… │ 0.22  │ [11.6, -10.605]    │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_R_contacts_b_contacts_W_… │ 0.22  │ [5.54, -10.605]    │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_R_contacts_c_contacts_E_… │ 0.22  │ [12.34, -10.605]   │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_R_contacts_c_contacts_W_… │ 0.22  │ [4.8, -10.605]     │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_contacts_e_row1_col0_W          │ 0.22  │ [-2.36, -10.475]   │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_contacts_e_row1_col1_W          │ 0.22  │ [-1.86, -10.475]   │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_contacts_e_row1_col2_W          │ 0.22  │ [-1.36, -10.475]   │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_contacts_e_row1_col3_W          │ 0.22  │ [-0.86, -10.475]   │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_contacts_e_row1_col4_W          │ 0.22  │ [-0.36, -10.475]   │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_contacts_e_row1_col5_W          │ 0.22  │ [0.14, -10.475]    │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_contacts_e_row1_col6_W          │ 0.22  │ [0.64, -10.475]    │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_contacts_e_row1_col7_W          │ 0.22  │ [1.14, -10.475]    │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_contacts_e_row1_col8_W          │ 0.22  │ [1.64, -10.475]    │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_contacts_e_row1_col9_W          │ 0.22  │ [2.14, -10.475]    │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_L_contacts_e_row1_col0_W  │ 0.22  │ [-11.04, -10.475]  │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_L_contacts_e_row1_col1_W  │ 0.22  │ [-10.54, -10.475]  │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_L_contacts_e_row1_col2_W  │ 0.22  │ [-10.04, -10.475]  │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_L_contacts_e_row1_col3_W  │ 0.22  │ [-9.54, -10.475]   │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_L_contacts_e_row1_col4_W  │ 0.22  │ [-9.04, -10.475]   │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_L_contacts_e_row1_col5_W  │ 0.22  │ [-8.54, -10.475]   │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_L_contacts_e_row1_col6_W  │ 0.22  │ [-8.04, -10.475]   │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_L_contacts_e_row1_col7_W  │ 0.22  │ [-7.54, -10.475]   │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_L_contacts_e_row1_col8_W  │ 0.22  │ [-7.04, -10.475]   │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_L_contacts_e_row1_col9_W  │ 0.22  │ [-6.54, -10.475]   │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_R_contacts_e_row1_col0_W  │ 0.22  │ [6.32, -10.475]    │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_R_contacts_e_row1_col1_W  │ 0.22  │ [6.82, -10.475]    │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_R_contacts_e_row1_col2_W  │ 0.22  │ [7.32, -10.475]    │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_R_contacts_e_row1_col3_W  │ 0.22  │ [7.82, -10.475]    │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_R_contacts_e_row1_col4_W  │ 0.22  │ [8.32, -10.475]    │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_R_contacts_e_row1_col5_W  │ 0.22  │ [8.82, -10.475]    │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_R_contacts_e_row1_col6_W  │ 0.22  │ [9.32, -10.475]    │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_R_contacts_e_row1_col7_W  │ 0.22  │ [9.82, -10.475]    │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_R_contacts_e_row1_col8_W  │ 0.22  │ [10.32, -10.475]   │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_R_contacts_e_row1_col9_W  │ 0.22  │ [10.82, -10.475]   │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_contacts_b_contacts_E_row3_col… │ 0.22  │ [2.92, -10.135]    │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_contacts_b_contacts_W_row3_col… │ 0.22  │ [-3.14, -10.135]   │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_contacts_c_contacts_E_row5_col… │ 0.22  │ [3.66, -10.135]    │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_contacts_c_contacts_W_row5_col… │ 0.22  │ [-3.88, -10.135]   │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_L_contacts_b_contacts_E_… │ 0.22  │ [-5.76, -10.135]   │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_L_contacts_b_contacts_W_… │ 0.22  │ [-11.82, -10.135]  │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_L_contacts_c_contacts_E_… │ 0.22  │ [-5.02, -10.135]   │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_L_contacts_c_contacts_W_… │ 0.22  │ [-12.56, -10.135]  │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_R_contacts_b_contacts_E_… │ 0.22  │ [11.6, -10.135]    │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_R_contacts_b_contacts_W_… │ 0.22  │ [5.54, -10.135]    │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_R_contacts_c_contacts_E_… │ 0.22  │ [12.34, -10.135]   │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_R_contacts_c_contacts_W_… │ 0.22  │ [4.8, -10.135]     │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_contacts_e_row2_col0_W          │ 0.22  │ [-2.36, -9.975]    │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_contacts_e_row2_col1_W          │ 0.22  │ [-1.86, -9.975]    │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_contacts_e_row2_col2_W          │ 0.22  │ [-1.36, -9.975]    │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_contacts_e_row2_col3_W          │ 0.22  │ [-0.86, -9.975]    │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_contacts_e_row2_col4_W          │ 0.22  │ [-0.36, -9.975]    │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_contacts_e_row2_col5_W          │ 0.22  │ [0.14, -9.975]     │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_contacts_e_row2_col6_W          │ 0.22  │ [0.64, -9.975]     │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_contacts_e_row2_col7_W          │ 0.22  │ [1.14, -9.975]     │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_contacts_e_row2_col8_W          │ 0.22  │ [1.64, -9.975]     │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_contacts_e_row2_col9_W          │ 0.22  │ [2.14, -9.975]     │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_L_contacts_e_row2_col0_W  │ 0.22  │ [-11.04, -9.975]   │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_L_contacts_e_row2_col1_W  │ 0.22  │ [-10.54, -9.975]   │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_L_contacts_e_row2_col2_W  │ 0.22  │ [-10.04, -9.975]   │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_L_contacts_e_row2_col3_W  │ 0.22  │ [-9.54, -9.975]    │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_L_contacts_e_row2_col4_W  │ 0.22  │ [-9.04, -9.975]    │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_L_contacts_e_row2_col5_W  │ 0.22  │ [-8.54, -9.975]    │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_L_contacts_e_row2_col6_W  │ 0.22  │ [-8.04, -9.975]    │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_L_contacts_e_row2_col7_W  │ 0.22  │ [-7.54, -9.975]    │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_L_contacts_e_row2_col8_W  │ 0.22  │ [-7.04, -9.975]    │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_L_contacts_e_row2_col9_W  │ 0.22  │ [-6.54, -9.975]    │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_R_contacts_e_row2_col0_W  │ 0.22  │ [6.32, -9.975]     │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_R_contacts_e_row2_col1_W  │ 0.22  │ [6.82, -9.975]     │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_R_contacts_e_row2_col2_W  │ 0.22  │ [7.32, -9.975]     │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_R_contacts_e_row2_col3_W  │ 0.22  │ [7.82, -9.975]     │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_R_contacts_e_row2_col4_W  │ 0.22  │ [8.32, -9.975]     │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_R_contacts_e_row2_col5_W  │ 0.22  │ [8.82, -9.975]     │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_R_contacts_e_row2_col6_W  │ 0.22  │ [9.32, -9.975]     │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_R_contacts_e_row2_col7_W  │ 0.22  │ [9.82, -9.975]     │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_R_contacts_e_row2_col8_W  │ 0.22  │ [10.32, -9.975]    │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_R_contacts_e_row2_col9_W  │ 0.22  │ [10.82, -9.975]    │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_contacts_b_contacts_E_row4_col… │ 0.22  │ [2.92, -9.665]     │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_contacts_b_contacts_W_row4_col… │ 0.22  │ [-3.14, -9.665]    │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_contacts_c_contacts_E_row6_col… │ 0.22  │ [3.66, -9.665]     │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_contacts_c_contacts_W_row6_col… │ 0.22  │ [-3.88, -9.665]    │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_L_contacts_b_contacts_E_… │ 0.22  │ [-5.76, -9.665]    │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_L_contacts_b_contacts_W_… │ 0.22  │ [-11.82, -9.665]   │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_L_contacts_c_contacts_E_… │ 0.22  │ [-5.02, -9.665]    │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_L_contacts_c_contacts_W_… │ 0.22  │ [-12.56, -9.665]   │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_R_contacts_b_contacts_E_… │ 0.22  │ [11.6, -9.665]     │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_R_contacts_b_contacts_W_… │ 0.22  │ [5.54, -9.665]     │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_R_contacts_c_contacts_E_… │ 0.22  │ [12.34, -9.665]    │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_R_contacts_c_contacts_W_… │ 0.22  │ [4.8, -9.665]      │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_contacts_e_row3_col0_W          │ 0.22  │ [-2.36, -9.475]    │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_contacts_e_row3_col1_W          │ 0.22  │ [-1.86, -9.475]    │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_contacts_e_row3_col2_W          │ 0.22  │ [-1.36, -9.475]    │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_contacts_e_row3_col3_W          │ 0.22  │ [-0.86, -9.475]    │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_contacts_e_row3_col4_W          │ 0.22  │ [-0.36, -9.475]    │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_contacts_e_row3_col5_W          │ 0.22  │ [0.14, -9.475]     │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_contacts_e_row3_col6_W          │ 0.22  │ [0.64, -9.475]     │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_contacts_e_row3_col7_W          │ 0.22  │ [1.14, -9.475]     │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_contacts_e_row3_col8_W          │ 0.22  │ [1.64, -9.475]     │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_contacts_e_row3_col9_W          │ 0.22  │ [2.14, -9.475]     │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_L_contacts_e_row3_col0_W  │ 0.22  │ [-11.04, -9.475]   │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_L_contacts_e_row3_col1_W  │ 0.22  │ [-10.54, -9.475]   │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_L_contacts_e_row3_col2_W  │ 0.22  │ [-10.04, -9.475]   │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_L_contacts_e_row3_col3_W  │ 0.22  │ [-9.54, -9.475]    │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_L_contacts_e_row3_col4_W  │ 0.22  │ [-9.04, -9.475]    │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_L_contacts_e_row3_col5_W  │ 0.22  │ [-8.54, -9.475]    │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_L_contacts_e_row3_col6_W  │ 0.22  │ [-8.04, -9.475]    │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_L_contacts_e_row3_col7_W  │ 0.22  │ [-7.54, -9.475]    │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_L_contacts_e_row3_col8_W  │ 0.22  │ [-7.04, -9.475]    │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_L_contacts_e_row3_col9_W  │ 0.22  │ [-6.54, -9.475]    │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_R_contacts_e_row3_col0_W  │ 0.22  │ [6.32, -9.475]     │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_R_contacts_e_row3_col1_W  │ 0.22  │ [6.82, -9.475]     │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_R_contacts_e_row3_col2_W  │ 0.22  │ [7.32, -9.475]     │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_R_contacts_e_row3_col3_W  │ 0.22  │ [7.82, -9.475]     │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_R_contacts_e_row3_col4_W  │ 0.22  │ [8.32, -9.475]     │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_R_contacts_e_row3_col5_W  │ 0.22  │ [8.82, -9.475]     │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_R_contacts_e_row3_col6_W  │ 0.22  │ [9.32, -9.475]     │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_R_contacts_e_row3_col7_W  │ 0.22  │ [9.82, -9.475]     │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_R_contacts_e_row3_col8_W  │ 0.22  │ [10.32, -9.475]    │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_R_contacts_e_row3_col9_W  │ 0.22  │ [10.82, -9.475]    │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_contacts_b_contacts_E_row5_col… │ 0.22  │ [2.92, -9.195]     │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_contacts_b_contacts_W_row5_col… │ 0.22  │ [-3.14, -9.195]    │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_contacts_c_contacts_E_row7_col… │ 0.22  │ [3.66, -9.195]     │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_contacts_c_contacts_W_row7_col… │ 0.22  │ [-3.88, -9.195]    │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_L_contacts_b_contacts_E_… │ 0.22  │ [-5.76, -9.195]    │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_L_contacts_b_contacts_W_… │ 0.22  │ [-11.82, -9.195]   │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_L_contacts_c_contacts_E_… │ 0.22  │ [-5.02, -9.195]    │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_L_contacts_c_contacts_W_… │ 0.22  │ [-12.56, -9.195]   │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_R_contacts_b_contacts_E_… │ 0.22  │ [11.6, -9.195]     │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_R_contacts_b_contacts_W_… │ 0.22  │ [5.54, -9.195]     │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_R_contacts_c_contacts_E_… │ 0.22  │ [12.34, -9.195]    │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_R_contacts_c_contacts_W_… │ 0.22  │ [4.8, -9.195]      │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_contacts_e_row4_col0_W          │ 0.22  │ [-2.36, -8.975]    │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_contacts_e_row4_col1_W          │ 0.22  │ [-1.86, -8.975]    │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_contacts_e_row4_col2_W          │ 0.22  │ [-1.36, -8.975]    │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_contacts_e_row4_col3_W          │ 0.22  │ [-0.86, -8.975]    │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_contacts_e_row4_col4_W          │ 0.22  │ [-0.36, -8.975]    │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_contacts_e_row4_col5_W          │ 0.22  │ [0.14, -8.975]     │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_contacts_e_row4_col6_W          │ 0.22  │ [0.64, -8.975]     │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_contacts_e_row4_col7_W          │ 0.22  │ [1.14, -8.975]     │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_contacts_e_row4_col8_W          │ 0.22  │ [1.64, -8.975]     │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_contacts_e_row4_col9_W          │ 0.22  │ [2.14, -8.975]     │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_L_contacts_e_row4_col0_W  │ 0.22  │ [-11.04, -8.975]   │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_L_contacts_e_row4_col1_W  │ 0.22  │ [-10.54, -8.975]   │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_L_contacts_e_row4_col2_W  │ 0.22  │ [-10.04, -8.975]   │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_L_contacts_e_row4_col3_W  │ 0.22  │ [-9.54, -8.975]    │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_L_contacts_e_row4_col4_W  │ 0.22  │ [-9.04, -8.975]    │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_L_contacts_e_row4_col5_W  │ 0.22  │ [-8.54, -8.975]    │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_L_contacts_e_row4_col6_W  │ 0.22  │ [-8.04, -8.975]    │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_L_contacts_e_row4_col7_W  │ 0.22  │ [-7.54, -8.975]    │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_L_contacts_e_row4_col8_W  │ 0.22  │ [-7.04, -8.975]    │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_L_contacts_e_row4_col9_W  │ 0.22  │ [-6.54, -8.975]    │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_R_contacts_e_row4_col0_W  │ 0.22  │ [6.32, -8.975]     │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_R_contacts_e_row4_col1_W  │ 0.22  │ [6.82, -8.975]     │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_R_contacts_e_row4_col2_W  │ 0.22  │ [7.32, -8.975]     │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_R_contacts_e_row4_col3_W  │ 0.22  │ [7.82, -8.975]     │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_R_contacts_e_row4_col4_W  │ 0.22  │ [8.32, -8.975]     │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_R_contacts_e_row4_col5_W  │ 0.22  │ [8.82, -8.975]     │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_R_contacts_e_row4_col6_W  │ 0.22  │ [9.32, -8.975]     │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_R_contacts_e_row4_col7_W  │ 0.22  │ [9.82, -8.975]     │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_R_contacts_e_row4_col8_W  │ 0.22  │ [10.32, -8.975]    │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_R_contacts_e_row4_col9_W  │ 0.22  │ [10.82, -8.975]    │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_diff_e_W                        │ 5.32  │ [-2.66, -8.725]    │ 180.0       │ [31, 0]  │ electrical │
# │ multiplier_0_tap_e_W                         │ 5.0   │ [-2.5, -8.725]     │ 180.0       │ [22, 0]  │ electrical │
# │ multiplier_0_well_W                          │ 6.8   │ [-3.4, -8.725]     │ 180.0       │ [21, 0]  │ electrical │
# │ multiplier_0_lvs_W                           │ 5.0   │ [-2.5, -8.725]     │ 180.0       │ [118, 5] │ electrical │
# │ multiplier_0_drc_W                           │ 8.28  │ [-4.14, -8.725]    │ 180.0       │ [127, 5] │ electrical │
# │ multiplier_0_E_W                             │ 5.0   │ [-2.5, -8.725]     │ 180.0       │ [34, 0]  │ electrical │
# │ multiplier_0_B_metal_E_W                     │ 6.48  │ [2.82, -8.725]     │ 180.0       │ [34, 0]  │ electrical │
# │ multiplier_0_B_metal_W_W                     │ 6.48  │ [-3.24, -8.725]    │ 180.0       │ [34, 0]  │ electrical │
# │ multiplier_0_C_metal_E_W                     │ 7.96  │ [3.56, -8.725]     │ 180.0       │ [34, 0]  │ electrical │
# │ multiplier_0_C_metal_W_W                     │ 7.96  │ [-3.98, -8.725]    │ 180.0       │ [34, 0]  │ electrical │
# │ multiplier_0_contacts_b_contacts_E_row6_col… │ 0.22  │ [2.92, -8.725]     │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_contacts_b_contacts_W_row6_col… │ 0.22  │ [-3.14, -8.725]    │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_contacts_c_contacts_E_row8_col… │ 0.22  │ [3.66, -8.725]     │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_contacts_c_contacts_W_row8_col… │ 0.22  │ [-3.88, -8.725]    │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_emitter_W                       │ 0.5   │ [-0.25, -8.725]    │ 180.0       │ [36, 0]  │ electrical │
# │ multiplier_0_dummy_L_diff_e_W                │ 5.32  │ [-11.34, -8.725]   │ 180.0       │ [31, 0]  │ electrical │
# │ multiplier_0_dummy_L_tap_e_W                 │ 5.0   │ [-11.18, -8.725]   │ 180.0       │ [22, 0]  │ electrical │
# │ multiplier_0_dummy_L_well_W                  │ 6.8   │ [-12.08, -8.725]   │ 180.0       │ [21, 0]  │ electrical │
# │ multiplier_0_dummy_L_lvs_W                   │ 5.0   │ [-11.18, -8.725]   │ 180.0       │ [118, 5] │ electrical │
# │ multiplier_0_dummy_L_drc_W                   │ 8.28  │ [-12.82, -8.725]   │ 180.0       │ [127, 5] │ electrical │
# │ multiplier_0_dummy_L_E_W                     │ 5.0   │ [-11.18, -8.725]   │ 180.0       │ [34, 0]  │ electrical │
# │ multiplier_0_dummy_L_B_metal_E_W             │ 6.48  │ [-5.86, -8.725]    │ 180.0       │ [34, 0]  │ electrical │
# │ multiplier_0_dummy_L_B_metal_W_W             │ 6.48  │ [-11.92, -8.725]   │ 180.0       │ [34, 0]  │ electrical │
# │ multiplier_0_dummy_L_C_metal_E_W             │ 7.96  │ [-5.12, -8.725]    │ 180.0       │ [34, 0]  │ electrical │
# │ multiplier_0_dummy_L_C_metal_W_W             │ 7.96  │ [-12.66, -8.725]   │ 180.0       │ [34, 0]  │ electrical │
# │ multiplier_0_dummy_L_contacts_b_contacts_E_… │ 0.22  │ [-5.76, -8.725]    │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_L_contacts_b_contacts_W_… │ 0.22  │ [-11.82, -8.725]   │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_L_contacts_c_contacts_E_… │ 0.22  │ [-5.02, -8.725]    │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_L_contacts_c_contacts_W_… │ 0.22  │ [-12.56, -8.725]   │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_R_diff_e_W                │ 5.32  │ [6.02, -8.725]     │ 180.0       │ [31, 0]  │ electrical │
# │ multiplier_0_dummy_R_tap_e_W                 │ 5.0   │ [6.18, -8.725]     │ 180.0       │ [22, 0]  │ electrical │
# │ multiplier_0_dummy_R_well_W                  │ 6.8   │ [5.28, -8.725]     │ 180.0       │ [21, 0]  │ electrical │
# │ multiplier_0_dummy_R_lvs_W                   │ 5.0   │ [6.18, -8.725]     │ 180.0       │ [118, 5] │ electrical │
# │ multiplier_0_dummy_R_drc_W                   │ 8.28  │ [4.54, -8.725]     │ 180.0       │ [127, 5] │ electrical │
# │ multiplier_0_dummy_R_E_W                     │ 5.0   │ [6.18, -8.725]     │ 180.0       │ [34, 0]  │ electrical │
# │ multiplier_0_dummy_R_B_metal_E_W             │ 6.48  │ [11.5, -8.725]     │ 180.0       │ [34, 0]  │ electrical │
# │ multiplier_0_dummy_R_B_metal_W_W             │ 6.48  │ [5.44, -8.725]     │ 180.0       │ [34, 0]  │ electrical │
# │ multiplier_0_dummy_R_C_metal_E_W             │ 7.96  │ [12.24, -8.725]    │ 180.0       │ [34, 0]  │ electrical │
# │ multiplier_0_dummy_R_C_metal_W_W             │ 7.96  │ [4.7, -8.725]      │ 180.0       │ [34, 0]  │ electrical │
# │ multiplier_0_dummy_R_contacts_b_contacts_E_… │ 0.22  │ [11.6, -8.725]     │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_R_contacts_b_contacts_W_… │ 0.22  │ [5.54, -8.725]     │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_R_contacts_c_contacts_E_… │ 0.22  │ [12.34, -8.725]    │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_R_contacts_c_contacts_W_… │ 0.22  │ [4.8, -8.725]      │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_contacts_e_row5_col0_W          │ 0.22  │ [-2.36, -8.475]    │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_contacts_e_row5_col1_W          │ 0.22  │ [-1.86, -8.475]    │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_contacts_e_row5_col2_W          │ 0.22  │ [-1.36, -8.475]    │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_contacts_e_row5_col3_W          │ 0.22  │ [-0.86, -8.475]    │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_contacts_e_row5_col4_W          │ 0.22  │ [-0.36, -8.475]    │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_contacts_e_row5_col5_W          │ 0.22  │ [0.14, -8.475]     │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_contacts_e_row5_col6_W          │ 0.22  │ [0.64, -8.475]     │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_contacts_e_row5_col7_W          │ 0.22  │ [1.14, -8.475]     │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_contacts_e_row5_col8_W          │ 0.22  │ [1.64, -8.475]     │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_contacts_e_row5_col9_W          │ 0.22  │ [2.14, -8.475]     │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_L_contacts_e_row5_col0_W  │ 0.22  │ [-11.04, -8.475]   │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_L_contacts_e_row5_col1_W  │ 0.22  │ [-10.54, -8.475]   │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_L_contacts_e_row5_col2_W  │ 0.22  │ [-10.04, -8.475]   │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_L_contacts_e_row5_col3_W  │ 0.22  │ [-9.54, -8.475]    │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_L_contacts_e_row5_col4_W  │ 0.22  │ [-9.04, -8.475]    │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_L_contacts_e_row5_col5_W  │ 0.22  │ [-8.54, -8.475]    │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_L_contacts_e_row5_col6_W  │ 0.22  │ [-8.04, -8.475]    │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_L_contacts_e_row5_col7_W  │ 0.22  │ [-7.54, -8.475]    │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_L_contacts_e_row5_col8_W  │ 0.22  │ [-7.04, -8.475]    │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_L_contacts_e_row5_col9_W  │ 0.22  │ [-6.54, -8.475]    │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_R_contacts_e_row5_col0_W  │ 0.22  │ [6.32, -8.475]     │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_R_contacts_e_row5_col1_W  │ 0.22  │ [6.82, -8.475]     │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_R_contacts_e_row5_col2_W  │ 0.22  │ [7.32, -8.475]     │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_R_contacts_e_row5_col3_W  │ 0.22  │ [7.82, -8.475]     │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_R_contacts_e_row5_col4_W  │ 0.22  │ [8.32, -8.475]     │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_R_contacts_e_row5_col5_W  │ 0.22  │ [8.82, -8.475]     │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_R_contacts_e_row5_col6_W  │ 0.22  │ [9.32, -8.475]     │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_R_contacts_e_row5_col7_W  │ 0.22  │ [9.82, -8.475]     │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_R_contacts_e_row5_col8_W  │ 0.22  │ [10.32, -8.475]    │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_R_contacts_e_row5_col9_W  │ 0.22  │ [10.82, -8.475]    │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_contacts_b_contacts_E_row7_col… │ 0.22  │ [2.92, -8.255]     │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_contacts_b_contacts_W_row7_col… │ 0.22  │ [-3.14, -8.255]    │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_contacts_c_contacts_E_row9_col… │ 0.22  │ [3.66, -8.255]     │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_contacts_c_contacts_W_row9_col… │ 0.22  │ [-3.88, -8.255]    │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_L_contacts_b_contacts_E_… │ 0.22  │ [-5.76, -8.255]    │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_L_contacts_b_contacts_W_… │ 0.22  │ [-11.82, -8.255]   │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_L_contacts_c_contacts_E_… │ 0.22  │ [-5.02, -8.255]    │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_L_contacts_c_contacts_W_… │ 0.22  │ [-12.56, -8.255]   │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_R_contacts_b_contacts_E_… │ 0.22  │ [11.6, -8.255]     │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_R_contacts_b_contacts_W_… │ 0.22  │ [5.54, -8.255]     │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_R_contacts_c_contacts_E_… │ 0.22  │ [12.34, -8.255]    │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_R_contacts_c_contacts_W_… │ 0.22  │ [4.8, -8.255]      │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_contacts_e_row6_col0_W          │ 0.22  │ [-2.36, -7.975]    │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_contacts_e_row6_col1_W          │ 0.22  │ [-1.86, -7.975]    │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_contacts_e_row6_col2_W          │ 0.22  │ [-1.36, -7.975]    │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_contacts_e_row6_col3_W          │ 0.22  │ [-0.86, -7.975]    │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_contacts_e_row6_col4_W          │ 0.22  │ [-0.36, -7.975]    │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_contacts_e_row6_col5_W          │ 0.22  │ [0.14, -7.975]     │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_contacts_e_row6_col6_W          │ 0.22  │ [0.64, -7.975]     │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_contacts_e_row6_col7_W          │ 0.22  │ [1.14, -7.975]     │ 180.0       │ [33, 0]  │ electrical │
# │ multiplier_0_contacts_e_row6_col8_W          │ 0.22  │ [1.64, -7.975]     │ 180.0       │ [33, 0]  │ electrical │
# ...
# │ multiplier_0_dummy_L_contacts_e_row8_col0_S  │ 0.22  │ [-10.93, -7.085]   │ 270.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_L_contacts_e_row9_col0_S  │ 0.22  │ [-10.93, -6.585]   │ 270.0       │ [33, 0]  │ electrical │
# │ multiplier_1_dummy_L_contacts_e_row0_col0_S  │ 0.22  │ [-10.93, -2.315]   │ 270.0       │ [33, 0]  │ electrical │
# │ multiplier_1_dummy_L_contacts_e_row1_col0_S  │ 0.22  │ [-10.93, -1.815]   │ 270.0       │ [33, 0]  │ electrical │
# │ multiplier_1_dummy_L_contacts_e_row2_col0_S  │ 0.22  │ [-10.93, -1.315]   │ 270.0       │ [33, 0]  │ electrical │
# │ multiplier_1_dummy_L_contacts_e_row3_col0_S  │ 0.22  │ [-10.93, -0.815]   │ 270.0       │ [33, 0]  │ electrical │
# │ multiplier_1_dummy_L_contacts_e_row4_col0_S  │ 0.22  │ [-10.93, -0.315]   │ 270.0       │ [33, 0]  │ electrical │
# │ multiplier_1_dummy_L_contacts_e_row5_col0_S  │ 0.22  │ [-10.93, 0.185]    │ 270.0       │ [33, 0]  │ electrical │
# │ multiplier_1_dummy_L_contacts_e_row6_col0_S  │ 0.22  │ [-10.93, 0.685]    │ 270.0       │ [33, 0]  │ electrical │
# │ multiplier_1_dummy_L_contacts_e_row7_col0_S  │ 0.22  │ [-10.93, 1.185]    │ 270.0       │ [33, 0]  │ electrical │
# │ multiplier_1_dummy_L_contacts_e_row8_col0_S  │ 0.22  │ [-10.93, 1.685]    │ 270.0       │ [33, 0]  │ electrical │
# │ multiplier_1_dummy_L_contacts_e_row9_col0_S  │ 0.22  │ [-10.93, 2.185]    │ 270.0       │ [33, 0]  │ electrical │
# │ multiplier_2_dummy_L_contacts_e_row0_col0_S  │ 0.22  │ [-10.93, 6.455]    │ 270.0       │ [33, 0]  │ electrical │
# │ multiplier_2_dummy_L_contacts_e_row1_col0_S  │ 0.22  │ [-10.93, 6.955]    │ 270.0       │ [33, 0]  │ electrical │
# │ multiplier_2_dummy_L_contacts_e_row2_col0_S  │ 0.22  │ [-10.93, 7.455]    │ 270.0       │ [33, 0]  │ electrical │
# │ multiplier_2_dummy_L_contacts_e_row3_col0_S  │ 0.22  │ [-10.93, 7.955]    │ 270.0       │ [33, 0]  │ electrical │
# │ multiplier_2_dummy_L_contacts_e_row4_col0_S  │ 0.22  │ [-10.93, 8.455]    │ 270.0       │ [33, 0]  │ electrical │
# │ multiplier_2_dummy_L_contacts_e_row5_col0_S  │ 0.22  │ [-10.93, 8.955]    │ 270.0       │ [33, 0]  │ electrical │
# │ multiplier_2_dummy_L_contacts_e_row6_col0_S  │ 0.22  │ [-10.93, 9.455]    │ 270.0       │ [33, 0]  │ electrical │
# │ multiplier_2_dummy_L_contacts_e_row7_col0_S  │ 0.22  │ [-10.93, 9.955]    │ 270.0       │ [33, 0]  │ electrical │
# │ multiplier_2_dummy_L_contacts_e_row8_col0_S  │ 0.22  │ [-10.93, 10.455]   │ 270.0       │ [33, 0]  │ electrical │
# │ multiplier_2_dummy_L_contacts_e_row9_col0_S  │ 0.22  │ [-10.93, 10.955]   │ 270.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_L_contacts_b_contacts_N_… │ 0.22  │ [-11.03, -5.805]   │ 270.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_L_contacts_b_contacts_S_… │ 0.22  │ [-11.03, -11.865]  │ 270.0       │ [33, 0]  │ electrical │
# │ multiplier_1_dummy_L_contacts_b_contacts_N_… │ 0.22  │ [-11.03, 2.965]    │ 270.0       │ [33, 0]  │ electrical │
# │ multiplier_1_dummy_L_contacts_b_contacts_S_… │ 0.22  │ [-11.03, -3.095]   │ 270.0       │ [33, 0]  │ electrical │
# │ multiplier_2_dummy_L_contacts_b_contacts_N_… │ 0.22  │ [-11.03, 11.735]   │ 270.0       │ [33, 0]  │ electrical │
# │ multiplier_2_dummy_L_contacts_b_contacts_S_… │ 0.22  │ [-11.03, 5.675]    │ 270.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_L_contacts_c_contacts_N_… │ 0.22  │ [-11.265, -5.065]  │ 270.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_L_contacts_c_contacts_S_… │ 0.22  │ [-11.265, -12.605] │ 270.0       │ [33, 0]  │ electrical │
# │ multiplier_1_dummy_L_contacts_c_contacts_N_… │ 0.22  │ [-11.265, 3.705]   │ 270.0       │ [33, 0]  │ electrical │
# │ multiplier_1_dummy_L_contacts_c_contacts_S_… │ 0.22  │ [-11.265, -3.835]  │ 270.0       │ [33, 0]  │ electrical │
# │ multiplier_2_dummy_L_contacts_c_contacts_N_… │ 0.22  │ [-11.265, 12.475]  │ 270.0       │ [33, 0]  │ electrical │
# │ multiplier_2_dummy_L_contacts_c_contacts_S_… │ 0.22  │ [-11.265, 4.935]   │ 270.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_L_B_metal_W_S             │ 0.42  │ [-11.71, -11.965]  │ 270.0       │ [34, 0]  │ electrical │
# │ multiplier_0_dummy_L_contacts_b_contacts_W_… │ 0.22  │ [-11.71, -11.655]  │ 270.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_L_contacts_b_contacts_W_… │ 0.22  │ [-11.71, -11.185]  │ 270.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_L_contacts_b_contacts_W_… │ 0.22  │ [-11.71, -10.715]  │ 270.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_L_contacts_b_contacts_W_… │ 0.22  │ [-11.71, -10.245]  │ 270.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_L_contacts_b_contacts_W_… │ 0.22  │ [-11.71, -9.775]   │ 270.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_L_contacts_b_contacts_W_… │ 0.22  │ [-11.71, -9.305]   │ 270.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_L_contacts_b_contacts_W_… │ 0.22  │ [-11.71, -8.835]   │ 270.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_L_contacts_b_contacts_W_… │ 0.22  │ [-11.71, -8.365]   │ 270.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_L_contacts_b_contacts_W_… │ 0.22  │ [-11.71, -7.895]   │ 270.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_L_contacts_b_contacts_W_… │ 0.22  │ [-11.71, -7.425]   │ 270.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_L_contacts_b_contacts_W_… │ 0.22  │ [-11.71, -6.955]   │ 270.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_L_contacts_b_contacts_W_… │ 0.22  │ [-11.71, -6.485]   │ 270.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_L_contacts_b_contacts_W_… │ 0.22  │ [-11.71, -6.015]   │ 270.0       │ [33, 0]  │ electrical │
# │ multiplier_1_dummy_L_B_metal_W_S             │ 0.42  │ [-11.71, -3.195]   │ 270.0       │ [34, 0]  │ electrical │
# │ multiplier_1_dummy_L_contacts_b_contacts_W_… │ 0.22  │ [-11.71, -2.885]   │ 270.0       │ [33, 0]  │ electrical │
# │ multiplier_1_dummy_L_contacts_b_contacts_W_… │ 0.22  │ [-11.71, -2.415]   │ 270.0       │ [33, 0]  │ electrical │
# │ multiplier_1_dummy_L_contacts_b_contacts_W_… │ 0.22  │ [-11.71, -1.945]   │ 270.0       │ [33, 0]  │ electrical │
# │ multiplier_1_dummy_L_contacts_b_contacts_W_… │ 0.22  │ [-11.71, -1.475]   │ 270.0       │ [33, 0]  │ electrical │
# │ multiplier_1_dummy_L_contacts_b_contacts_W_… │ 0.22  │ [-11.71, -1.005]   │ 270.0       │ [33, 0]  │ electrical │
# │ multiplier_1_dummy_L_contacts_b_contacts_W_… │ 0.22  │ [-11.71, -0.535]   │ 270.0       │ [33, 0]  │ electrical │
# │ multiplier_1_dummy_L_contacts_b_contacts_W_… │ 0.22  │ [-11.71, -0.065]   │ 270.0       │ [33, 0]  │ electrical │
# │ multiplier_1_dummy_L_contacts_b_contacts_W_… │ 0.22  │ [-11.71, 0.405]    │ 270.0       │ [33, 0]  │ electrical │
# │ multiplier_1_dummy_L_contacts_b_contacts_W_… │ 0.22  │ [-11.71, 0.875]    │ 270.0       │ [33, 0]  │ electrical │
# │ multiplier_1_dummy_L_contacts_b_contacts_W_… │ 0.22  │ [-11.71, 1.345]    │ 270.0       │ [33, 0]  │ electrical │
# │ multiplier_1_dummy_L_contacts_b_contacts_W_… │ 0.22  │ [-11.71, 1.815]    │ 270.0       │ [33, 0]  │ electrical │
# │ multiplier_1_dummy_L_contacts_b_contacts_W_… │ 0.22  │ [-11.71, 2.285]    │ 270.0       │ [33, 0]  │ electrical │
# │ multiplier_1_dummy_L_contacts_b_contacts_W_… │ 0.22  │ [-11.71, 2.755]    │ 270.0       │ [33, 0]  │ electrical │
# │ multiplier_2_dummy_L_B_metal_W_S             │ 0.42  │ [-11.71, 5.575]    │ 270.0       │ [34, 0]  │ electrical │
# │ multiplier_2_dummy_L_contacts_b_contacts_W_… │ 0.22  │ [-11.71, 5.885]    │ 270.0       │ [33, 0]  │ electrical │
# │ multiplier_2_dummy_L_contacts_b_contacts_W_… │ 0.22  │ [-11.71, 6.355]    │ 270.0       │ [33, 0]  │ electrical │
# │ multiplier_2_dummy_L_contacts_b_contacts_W_… │ 0.22  │ [-11.71, 6.825]    │ 270.0       │ [33, 0]  │ electrical │
# │ multiplier_2_dummy_L_contacts_b_contacts_W_… │ 0.22  │ [-11.71, 7.295]    │ 270.0       │ [33, 0]  │ electrical │
# │ multiplier_2_dummy_L_contacts_b_contacts_W_… │ 0.22  │ [-11.71, 7.765]    │ 270.0       │ [33, 0]  │ electrical │
# │ multiplier_2_dummy_L_contacts_b_contacts_W_… │ 0.22  │ [-11.71, 8.235]    │ 270.0       │ [33, 0]  │ electrical │
# │ multiplier_2_dummy_L_contacts_b_contacts_W_… │ 0.22  │ [-11.71, 8.705]    │ 270.0       │ [33, 0]  │ electrical │
# │ multiplier_2_dummy_L_contacts_b_contacts_W_… │ 0.22  │ [-11.71, 9.175]    │ 270.0       │ [33, 0]  │ electrical │
# │ multiplier_2_dummy_L_contacts_b_contacts_W_… │ 0.22  │ [-11.71, 9.645]    │ 270.0       │ [33, 0]  │ electrical │
# │ multiplier_2_dummy_L_contacts_b_contacts_W_… │ 0.22  │ [-11.71, 10.115]   │ 270.0       │ [33, 0]  │ electrical │
# │ multiplier_2_dummy_L_contacts_b_contacts_W_… │ 0.22  │ [-11.71, 10.585]   │ 270.0       │ [33, 0]  │ electrical │
# │ multiplier_2_dummy_L_contacts_b_contacts_W_… │ 0.22  │ [-11.71, 11.055]   │ 270.0       │ [33, 0]  │ electrical │
# │ multiplier_2_dummy_L_contacts_b_contacts_W_… │ 0.22  │ [-11.71, 11.525]   │ 270.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_L_contacts_c_contacts_N_… │ 0.22  │ [-11.735, -5.065]  │ 270.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_L_contacts_c_contacts_S_… │ 0.22  │ [-11.735, -12.605] │ 270.0       │ [33, 0]  │ electrical │
# │ multiplier_1_dummy_L_contacts_c_contacts_N_… │ 0.22  │ [-11.735, 3.705]   │ 270.0       │ [33, 0]  │ electrical │
# │ multiplier_1_dummy_L_contacts_c_contacts_S_… │ 0.22  │ [-11.735, -3.835]  │ 270.0       │ [33, 0]  │ electrical │
# │ multiplier_2_dummy_L_contacts_c_contacts_N_… │ 0.22  │ [-11.735, 12.475]  │ 270.0       │ [33, 0]  │ electrical │
# │ multiplier_2_dummy_L_contacts_c_contacts_S_… │ 0.22  │ [-11.735, 4.935]   │ 270.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_L_C_metal_W_S             │ 0.42  │ [-12.45, -12.705]  │ 270.0       │ [34, 0]  │ electrical │
# │ multiplier_0_dummy_L_contacts_c_contacts_W_… │ 0.22  │ [-12.45, -12.595]  │ 270.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_L_contacts_c_contacts_W_… │ 0.22  │ [-12.45, -12.125]  │ 270.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_L_contacts_c_contacts_W_… │ 0.22  │ [-12.45, -11.655]  │ 270.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_L_contacts_c_contacts_W_… │ 0.22  │ [-12.45, -11.185]  │ 270.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_L_contacts_c_contacts_W_… │ 0.22  │ [-12.45, -10.715]  │ 270.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_L_contacts_c_contacts_W_… │ 0.22  │ [-12.45, -10.245]  │ 270.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_L_contacts_c_contacts_W_… │ 0.22  │ [-12.45, -9.775]   │ 270.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_L_contacts_c_contacts_W_… │ 0.22  │ [-12.45, -9.305]   │ 270.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_L_contacts_c_contacts_W_… │ 0.22  │ [-12.45, -8.835]   │ 270.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_L_contacts_c_contacts_W_… │ 0.22  │ [-12.45, -8.365]   │ 270.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_L_contacts_c_contacts_W_… │ 0.22  │ [-12.45, -7.895]   │ 270.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_L_contacts_c_contacts_W_… │ 0.22  │ [-12.45, -7.425]   │ 270.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_L_contacts_c_contacts_W_… │ 0.22  │ [-12.45, -6.955]   │ 270.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_L_contacts_c_contacts_W_… │ 0.22  │ [-12.45, -6.485]   │ 270.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_L_contacts_c_contacts_W_… │ 0.22  │ [-12.45, -6.015]   │ 270.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_L_contacts_c_contacts_W_… │ 0.22  │ [-12.45, -5.545]   │ 270.0       │ [33, 0]  │ electrical │
# │ multiplier_0_dummy_L_contacts_c_contacts_W_… │ 0.22  │ [-12.45, -5.075]   │ 270.0       │ [33, 0]  │ electrical │
# │ multiplier_1_dummy_L_C_metal_W_S             │ 0.42  │ [-12.45, -3.935]   │ 270.0       │ [34, 0]  │ electrical │
# │ multiplier_1_dummy_L_contacts_c_contacts_W_… │ 0.22  │ [-12.45, -3.825]   │ 270.0       │ [33, 0]  │ electrical │
# │ multiplier_1_dummy_L_contacts_c_contacts_W_… │ 0.22  │ [-12.45, -3.355]   │ 270.0       │ [33, 0]  │ electrical │
# │ multiplier_1_dummy_L_contacts_c_contacts_W_… │ 0.22  │ [-12.45, -2.885]   │ 270.0       │ [33, 0]  │ electrical │
# │ multiplier_1_dummy_L_contacts_c_contacts_W_… │ 0.22  │ [-12.45, -2.415]   │ 270.0       │ [33, 0]  │ electrical │
# │ multiplier_1_dummy_L_contacts_c_contacts_W_… │ 0.22  │ [-12.45, -1.945]   │ 270.0       │ [33, 0]  │ electrical │
# │ multiplier_1_dummy_L_contacts_c_contacts_W_… │ 0.22  │ [-12.45, -1.475]   │ 270.0       │ [33, 0]  │ electrical │
# │ multiplier_1_dummy_L_contacts_c_contacts_W_… │ 0.22  │ [-12.45, -1.005]   │ 270.0       │ [33, 0]  │ electrical │
# │ multiplier_1_dummy_L_contacts_c_contacts_W_… │ 0.22  │ [-12.45, -0.535]   │ 270.0       │ [33, 0]  │ electrical │
# │ multiplier_1_dummy_L_contacts_c_contacts_W_… │ 0.22  │ [-12.45, -0.065]   │ 270.0       │ [33, 0]  │ electrical │
# │ multiplier_1_dummy_L_contacts_c_contacts_W_… │ 0.22  │ [-12.45, 0.405]    │ 270.0       │ [33, 0]  │ electrical │
# │ multiplier_1_dummy_L_contacts_c_contacts_W_… │ 0.22  │ [-12.45, 0.875]    │ 270.0       │ [33, 0]  │ electrical │
# │ multiplier_1_dummy_L_contacts_c_contacts_W_… │ 0.22  │ [-12.45, 1.345]    │ 270.0       │ [33, 0]  │ electrical │
# │ multiplier_1_dummy_L_contacts_c_contacts_W_… │ 0.22  │ [-12.45, 1.815]    │ 270.0       │ [33, 0]  │ electrical │
# │ multiplier_1_dummy_L_contacts_c_contacts_W_… │ 0.22  │ [-12.45, 2.285]    │ 270.0       │ [33, 0]  │ electrical │
# │ multiplier_1_dummy_L_contacts_c_contacts_W_… │ 0.22  │ [-12.45, 2.755]    │ 270.0       │ [33, 0]  │ electrical │
# │ multiplier_1_dummy_L_contacts_c_contacts_W_… │ 0.22  │ [-12.45, 3.225]    │ 270.0       │ [33, 0]  │ electrical │
# │ multiplier_1_dummy_L_contacts_c_contacts_W_… │ 0.22  │ [-12.45, 3.695]    │ 270.0       │ [33, 0]  │ electrical │
# │ multiplier_2_dummy_L_C_metal_W_S             │ 0.42  │ [-12.45, 4.835]    │ 270.0       │ [34, 0]  │ electrical │
# │ multiplier_2_dummy_L_contacts_c_contacts_W_… │ 0.22  │ [-12.45, 4.945]    │ 270.0       │ [33, 0]  │ electrical │
# │ multiplier_2_dummy_L_contacts_c_contacts_W_… │ 0.22  │ [-12.45, 5.415]    │ 270.0       │ [33, 0]  │ electrical │
# │ multiplier_2_dummy_L_contacts_c_contacts_W_… │ 0.22  │ [-12.45, 5.885]    │ 270.0       │ [33, 0]  │ electrical │
# │ multiplier_2_dummy_L_contacts_c_contacts_W_… │ 0.22  │ [-12.45, 6.355]    │ 270.0       │ [33, 0]  │ electrical │
# │ multiplier_2_dummy_L_contacts_c_contacts_W_… │ 0.22  │ [-12.45, 6.825]    │ 270.0       │ [33, 0]  │ electrical │
# │ multiplier_2_dummy_L_contacts_c_contacts_W_… │ 0.22  │ [-12.45, 7.295]    │ 270.0       │ [33, 0]  │ electrical │
# │ multiplier_2_dummy_L_contacts_c_contacts_W_… │ 0.22  │ [-12.45, 7.765]    │ 270.0       │ [33, 0]  │ electrical │
# │ multiplier_2_dummy_L_contacts_c_contacts_W_… │ 0.22  │ [-12.45, 8.235]    │ 270.0       │ [33, 0]  │ electrical │
# │ multiplier_2_dummy_L_contacts_c_contacts_W_… │ 0.22  │ [-12.45, 8.705]    │ 270.0       │ [33, 0]  │ electrical │
# │ multiplier_2_dummy_L_contacts_c_contacts_W_… │ 0.22  │ [-12.45, 9.175]    │ 270.0       │ [33, 0]  │ electrical │
# │ multiplier_2_dummy_L_contacts_c_contacts_W_… │ 0.22  │ [-12.45, 9.645]    │ 270.0       │ [33, 0]  │ electrical │
# │ multiplier_2_dummy_L_contacts_c_contacts_W_… │ 0.22  │ [-12.45, 10.115]   │ 270.0       │ [33, 0]  │ electrical │
# │ multiplier_2_dummy_L_contacts_c_contacts_W_… │ 0.22  │ [-12.45, 10.585]   │ 270.0       │ [33, 0]  │ electrical │
# │ multiplier_2_dummy_L_contacts_c_contacts_W_… │ 0.22  │ [-12.45, 11.055]   │ 270.0       │ [33, 0]  │ electrical │
# │ multiplier_2_dummy_L_contacts_c_contacts_W_… │ 0.22  │ [-12.45, 11.525]   │ 270.0       │ [33, 0]  │ electrical │
# │ multiplier_2_dummy_L_contacts_c_contacts_W_… │ 0.22  │ [-12.45, 11.995]   │ 270.0       │ [33, 0]  │ electrical │
# │ multiplier_2_dummy_L_contacts_c_contacts_W_… │ 0.22  │ [-12.45, 12.465]   │ 270.0       │ [33, 0]  │ electrical │
# └──────────────────────────────────────────────┴───────┴────────────────────┴─────────────┴──────────┴────────────┘

# %%
from glayout.primitives.bjt import pnp, npn

# %%
bjt_pnp=pnp(pdk=pdk,active_area=(5,5),bc_rmult=1,multipliers=4, pattern=["A","B","C","D"],is_bc_short=True)

# %%
bjt_pnp.show()
# Out:
# /headless/conda-env/miniconda3/envs/GLdev/lib/python3.10/site-packages/gdsfactory/show.py:40: UserWarning: Unnamed cells, 1 in 'Unnamed_d37866e2'
#   gdspath = component.write_gds(
# 2025-09-03 07:14:24.476 | INFO     | gdsfactory.klive:show:55 - Message from klive: {"version": "0.3.3", "klayout_version": "0.30.2", "type": "open", "file": "/tmp/gdsfactory/Unnamed_d37866e2.gds"}

# %%
pattern=[["a","b","c"],["a","b","c"]]

# %%
from glayout.util.pattern import check_pattern_level, transpose_pattern

# %%
check_pattern_level(pattern)
# Out:
# 2

# %%
transpose_pattern(pattern)
# Out:
# [['a', 'a'], ['b', 'b'], ['c', 'c']]

# %%
from glayout.primitives.bjt import multiplier, __mult_array_macro, __mult_2dim_array_macro

# %%
bjt_2dim_array= __mult_2dim_array_macro(pdk=pdk,active_area=(5,5),bjt_type="pnp",bc_rmult=1,
                       multipliers=(3,3),
                       pattern=[["A","C","B"],["B","A","A"],["A","C","B"]], is_bc_shared=True)
# Out:
# {'B': [0, 2], 'C': [1], 'A': [0, 1, 2]}
# col_0_base_S
# col_0_base_S
# 1.1
# 0 B
# col_0_B_emitter_N
# col_2_B_emitter_N
# 1 C
# 2 A
# col_0_A_emitter_N
# col_1_A_emitter_N
# col_1_A_emitter_N
# col_2_A_emitter_N

# %%
bjt_2dim_array.show()
# Out:
# /headless/conda-env/miniconda3/envs/GLdev/lib/python3.10/site-packages/gdsfactory/show.py:40: UserWarning: Unnamed cells, 3 in 'temp_multiplier_array$23'
#   gdspath = component.write_gds(
# 2025-09-08 06:21:24.740 | INFO     | gdsfactory.klive:show:55 - Message from klive: {"version": "0.3.3", "klayout_version": "0.30.2", "type": "open", "file": "/tmp/gdsfactory/temp_multiplier_array$23.gds"}

# %%
pattern= [["A","C","B"],["B","A","A"],["A","C","B"]]

# %%
from glayout.util.pattern import get_cols_positions

# %%
get_cols_positions(pattern)
# Out:
# {'C': [1], 'A': [0, 1, 2], 'B': [0, 2]}

# %%
get_cols_positions(pattern).keys()
# Out:
# dict_keys(['C', 'A', 'B'])

# %%
bjt_2dim_array.pprint_ports()
# Out:
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━┳━━━━━━━━━━┳━━━━━━━━━━━━┓
# ┃ name                                          ┃ width ┃ center            ┃ orientation ┃ layer    ┃ port_type  ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━╇━━━━━━━━━━╇━━━━━━━━━━━━┩
# │ col_0_multiplier_0_C_metal_S_W                │ 0.42  │ [-16.94, -12.45]  │ 180.0       │ [34, 0]  │ electrical │
# │ col_0_multiplier_0_contacts_c_contacts_S_row… │ 0.22  │ [-16.125, -12.45] │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_contacts_c_contacts_S_row… │ 0.22  │ [-15.655, -12.45] │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_contacts_c_contacts_S_row… │ 0.22  │ [-15.185, -12.45] │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_contacts_c_contacts_S_row… │ 0.22  │ [-14.715, -12.45] │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_contacts_c_contacts_S_row… │ 0.22  │ [-14.245, -12.45] │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_contacts_c_contacts_S_row… │ 0.22  │ [-13.775, -12.45] │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_contacts_c_contacts_S_row… │ 0.22  │ [-13.305, -12.45] │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_contacts_c_contacts_S_row… │ 0.22  │ [-12.835, -12.45] │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_contacts_c_contacts_S_row… │ 0.22  │ [-12.365, -12.45] │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_contacts_c_contacts_S_row… │ 0.22  │ [-11.895, -12.45] │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_contacts_c_contacts_S_row… │ 0.22  │ [-11.425, -12.45] │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_contacts_c_contacts_S_row… │ 0.22  │ [-10.955, -12.45] │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_contacts_c_contacts_S_row… │ 0.22  │ [-10.485, -12.45] │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_contacts_c_contacts_S_row… │ 0.22  │ [-10.015, -12.45] │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_dummy_L_C_metal_S_W        │ 0.42  │ [-25.62, -12.45]  │ 180.0       │ [34, 0]  │ electrical │
# │ col_0_multiplier_0_dummy_L_contacts_c_contac… │ 0.22  │ [-24.805, -12.45] │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_dummy_L_contacts_c_contac… │ 0.22  │ [-24.335, -12.45] │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_dummy_L_contacts_c_contac… │ 0.22  │ [-23.865, -12.45] │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_dummy_L_contacts_c_contac… │ 0.22  │ [-23.395, -12.45] │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_dummy_L_contacts_c_contac… │ 0.22  │ [-22.925, -12.45] │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_dummy_L_contacts_c_contac… │ 0.22  │ [-22.455, -12.45] │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_dummy_L_contacts_c_contac… │ 0.22  │ [-21.985, -12.45] │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_dummy_L_contacts_c_contac… │ 0.22  │ [-21.515, -12.45] │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_dummy_L_contacts_c_contac… │ 0.22  │ [-21.045, -12.45] │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_dummy_L_contacts_c_contac… │ 0.22  │ [-20.575, -12.45] │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_dummy_L_contacts_c_contac… │ 0.22  │ [-20.105, -12.45] │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_dummy_L_contacts_c_contac… │ 0.22  │ [-19.635, -12.45] │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_dummy_L_contacts_c_contac… │ 0.22  │ [-19.165, -12.45] │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_dummy_L_contacts_c_contac… │ 0.22  │ [-18.695, -12.45] │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_contacts_c_contacts_E_row… │ 0.22  │ [-9.3, -12.44]    │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_contacts_c_contacts_W_row… │ 0.22  │ [-16.84, -12.44]  │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_dummy_L_contacts_c_contac… │ 0.22  │ [-17.98, -12.44]  │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_dummy_L_contacts_c_contac… │ 0.22  │ [-25.52, -12.44]  │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_collector_W                │ 0.5   │ [-16.98, -12.41]  │ 180.0       │ [36, 0]  │ electrical │
# │ col_0_collector_W                             │ 0.5   │ [-16.98, -12.41]  │ 180.0       │ [36, 0]  │ electrical │
# │ col_0_multiplier_0_contacts_c_contacts_E_row… │ 0.22  │ [-9.3, -11.97]    │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_contacts_c_contacts_W_row… │ 0.22  │ [-16.84, -11.97]  │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_dummy_L_contacts_c_contac… │ 0.22  │ [-17.98, -11.97]  │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_dummy_L_contacts_c_contac… │ 0.22  │ [-25.52, -11.97]  │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_B_metal_S_W                │ 0.42  │ [-16.2, -11.71]   │ 180.0       │ [34, 0]  │ electrical │
# │ col_0_multiplier_0_contacts_b_contacts_S_row… │ 0.22  │ [-15.42, -11.71]  │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_contacts_b_contacts_S_row… │ 0.22  │ [-14.95, -11.71]  │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_contacts_b_contacts_S_row… │ 0.22  │ [-14.48, -11.71]  │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_contacts_b_contacts_S_row… │ 0.22  │ [-14.01, -11.71]  │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_contacts_b_contacts_S_row… │ 0.22  │ [-13.54, -11.71]  │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_contacts_b_contacts_S_row… │ 0.22  │ [-13.07, -11.71]  │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_contacts_b_contacts_S_row… │ 0.22  │ [-12.6, -11.71]   │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_contacts_b_contacts_S_row… │ 0.22  │ [-12.13, -11.71]  │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_contacts_b_contacts_S_row… │ 0.22  │ [-11.66, -11.71]  │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_contacts_b_contacts_S_row… │ 0.22  │ [-11.19, -11.71]  │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_contacts_b_contacts_S_row… │ 0.22  │ [-10.72, -11.71]  │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_dummy_L_B_metal_S_W        │ 0.42  │ [-24.88, -11.71]  │ 180.0       │ [34, 0]  │ electrical │
# │ col_0_multiplier_0_dummy_L_contacts_b_contac… │ 0.22  │ [-24.1, -11.71]   │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_dummy_L_contacts_b_contac… │ 0.22  │ [-23.63, -11.71]  │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_dummy_L_contacts_b_contac… │ 0.22  │ [-23.16, -11.71]  │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_dummy_L_contacts_b_contac… │ 0.22  │ [-22.69, -11.71]  │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_dummy_L_contacts_b_contac… │ 0.22  │ [-22.22, -11.71]  │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_dummy_L_contacts_b_contac… │ 0.22  │ [-21.75, -11.71]  │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_dummy_L_contacts_b_contac… │ 0.22  │ [-21.28, -11.71]  │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_dummy_L_contacts_b_contac… │ 0.22  │ [-20.81, -11.71]  │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_dummy_L_contacts_b_contac… │ 0.22  │ [-20.34, -11.71]  │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_dummy_L_contacts_b_contac… │ 0.22  │ [-19.87, -11.71]  │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_dummy_L_contacts_b_contac… │ 0.22  │ [-19.4, -11.71]   │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_contacts_b_contacts_E_row… │ 0.22  │ [-10.04, -11.5]   │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_contacts_b_contacts_W_row… │ 0.22  │ [-16.1, -11.5]    │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_contacts_c_contacts_E_row… │ 0.22  │ [-9.3, -11.5]     │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_contacts_c_contacts_W_row… │ 0.22  │ [-16.84, -11.5]   │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_dummy_L_contacts_b_contac… │ 0.22  │ [-18.72, -11.5]   │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_dummy_L_contacts_b_contac… │ 0.22  │ [-24.78, -11.5]   │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_dummy_L_contacts_c_contac… │ 0.22  │ [-17.98, -11.5]   │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_dummy_L_contacts_c_contac… │ 0.22  │ [-25.52, -11.5]   │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_contacts_b_contacts_E_row… │ 0.22  │ [-10.04, -11.03]  │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_contacts_b_contacts_W_row… │ 0.22  │ [-16.1, -11.03]   │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_contacts_c_contacts_E_row… │ 0.22  │ [-9.3, -11.03]    │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_contacts_c_contacts_W_row… │ 0.22  │ [-16.84, -11.03]  │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_dummy_L_contacts_b_contac… │ 0.22  │ [-18.72, -11.03]  │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_dummy_L_contacts_b_contac… │ 0.22  │ [-24.78, -11.03]  │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_dummy_L_contacts_c_contac… │ 0.22  │ [-17.98, -11.03]  │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_dummy_L_contacts_c_contac… │ 0.22  │ [-25.52, -11.03]  │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_contacts_e_row0_col0_W     │ 0.22  │ [-15.32, -10.93]  │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_contacts_e_row0_col1_W     │ 0.22  │ [-14.82, -10.93]  │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_contacts_e_row0_col2_W     │ 0.22  │ [-14.32, -10.93]  │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_contacts_e_row0_col3_W     │ 0.22  │ [-13.82, -10.93]  │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_contacts_e_row0_col4_W     │ 0.22  │ [-13.32, -10.93]  │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_contacts_e_row0_col5_W     │ 0.22  │ [-12.82, -10.93]  │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_contacts_e_row0_col6_W     │ 0.22  │ [-12.32, -10.93]  │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_contacts_e_row0_col7_W     │ 0.22  │ [-11.82, -10.93]  │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_contacts_e_row0_col8_W     │ 0.22  │ [-11.32, -10.93]  │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_contacts_e_row0_col9_W     │ 0.22  │ [-10.82, -10.93]  │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_dummy_L_contacts_e_row0_c… │ 0.22  │ [-24.0, -10.93]   │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_dummy_L_contacts_e_row0_c… │ 0.22  │ [-23.5, -10.93]   │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_dummy_L_contacts_e_row0_c… │ 0.22  │ [-23.0, -10.93]   │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_dummy_L_contacts_e_row0_c… │ 0.22  │ [-22.5, -10.93]   │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_dummy_L_contacts_e_row0_c… │ 0.22  │ [-22.0, -10.93]   │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_dummy_L_contacts_e_row0_c… │ 0.22  │ [-21.5, -10.93]   │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_dummy_L_contacts_e_row0_c… │ 0.22  │ [-21.0, -10.93]   │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_dummy_L_contacts_e_row0_c… │ 0.22  │ [-20.5, -10.93]   │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_dummy_L_contacts_e_row0_c… │ 0.22  │ [-20.0, -10.93]   │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_dummy_L_contacts_e_row0_c… │ 0.22  │ [-19.5, -10.93]   │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_contacts_b_contacts_E_row… │ 0.22  │ [-10.04, -10.56]  │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_contacts_b_contacts_W_row… │ 0.22  │ [-16.1, -10.56]   │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_contacts_c_contacts_E_row… │ 0.22  │ [-9.3, -10.56]    │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_contacts_c_contacts_W_row… │ 0.22  │ [-16.84, -10.56]  │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_dummy_L_contacts_b_contac… │ 0.22  │ [-18.72, -10.56]  │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_dummy_L_contacts_b_contac… │ 0.22  │ [-24.78, -10.56]  │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_dummy_L_contacts_c_contac… │ 0.22  │ [-17.98, -10.56]  │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_dummy_L_contacts_c_contac… │ 0.22  │ [-25.52, -10.56]  │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_contacts_e_row1_col0_W     │ 0.22  │ [-15.32, -10.43]  │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_contacts_e_row1_col1_W     │ 0.22  │ [-14.82, -10.43]  │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_contacts_e_row1_col2_W     │ 0.22  │ [-14.32, -10.43]  │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_contacts_e_row1_col3_W     │ 0.22  │ [-13.82, -10.43]  │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_contacts_e_row1_col4_W     │ 0.22  │ [-13.32, -10.43]  │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_contacts_e_row1_col5_W     │ 0.22  │ [-12.82, -10.43]  │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_contacts_e_row1_col6_W     │ 0.22  │ [-12.32, -10.43]  │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_contacts_e_row1_col7_W     │ 0.22  │ [-11.82, -10.43]  │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_contacts_e_row1_col8_W     │ 0.22  │ [-11.32, -10.43]  │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_contacts_e_row1_col9_W     │ 0.22  │ [-10.82, -10.43]  │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_dummy_L_contacts_e_row1_c… │ 0.22  │ [-24.0, -10.43]   │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_dummy_L_contacts_e_row1_c… │ 0.22  │ [-23.5, -10.43]   │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_dummy_L_contacts_e_row1_c… │ 0.22  │ [-23.0, -10.43]   │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_dummy_L_contacts_e_row1_c… │ 0.22  │ [-22.5, -10.43]   │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_dummy_L_contacts_e_row1_c… │ 0.22  │ [-22.0, -10.43]   │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_dummy_L_contacts_e_row1_c… │ 0.22  │ [-21.5, -10.43]   │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_dummy_L_contacts_e_row1_c… │ 0.22  │ [-21.0, -10.43]   │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_dummy_L_contacts_e_row1_c… │ 0.22  │ [-20.5, -10.43]   │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_dummy_L_contacts_e_row1_c… │ 0.22  │ [-20.0, -10.43]   │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_dummy_L_contacts_e_row1_c… │ 0.22  │ [-19.5, -10.43]   │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_contacts_b_contacts_E_row… │ 0.22  │ [-10.04, -10.09]  │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_contacts_b_contacts_W_row… │ 0.22  │ [-16.1, -10.09]   │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_contacts_c_contacts_E_row… │ 0.22  │ [-9.3, -10.09]    │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_contacts_c_contacts_W_row… │ 0.22  │ [-16.84, -10.09]  │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_dummy_L_contacts_b_contac… │ 0.22  │ [-18.72, -10.09]  │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_dummy_L_contacts_b_contac… │ 0.22  │ [-24.78, -10.09]  │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_dummy_L_contacts_c_contac… │ 0.22  │ [-17.98, -10.09]  │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_dummy_L_contacts_c_contac… │ 0.22  │ [-25.52, -10.09]  │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_contacts_e_row2_col0_W     │ 0.22  │ [-15.32, -9.93]   │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_contacts_e_row2_col1_W     │ 0.22  │ [-14.82, -9.93]   │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_contacts_e_row2_col2_W     │ 0.22  │ [-14.32, -9.93]   │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_contacts_e_row2_col3_W     │ 0.22  │ [-13.82, -9.93]   │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_contacts_e_row2_col4_W     │ 0.22  │ [-13.32, -9.93]   │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_contacts_e_row2_col5_W     │ 0.22  │ [-12.82, -9.93]   │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_contacts_e_row2_col6_W     │ 0.22  │ [-12.32, -9.93]   │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_contacts_e_row2_col7_W     │ 0.22  │ [-11.82, -9.93]   │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_contacts_e_row2_col8_W     │ 0.22  │ [-11.32, -9.93]   │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_contacts_e_row2_col9_W     │ 0.22  │ [-10.82, -9.93]   │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_dummy_L_contacts_e_row2_c… │ 0.22  │ [-24.0, -9.93]    │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_dummy_L_contacts_e_row2_c… │ 0.22  │ [-23.5, -9.93]    │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_dummy_L_contacts_e_row2_c… │ 0.22  │ [-23.0, -9.93]    │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_dummy_L_contacts_e_row2_c… │ 0.22  │ [-22.5, -9.93]    │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_dummy_L_contacts_e_row2_c… │ 0.22  │ [-22.0, -9.93]    │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_dummy_L_contacts_e_row2_c… │ 0.22  │ [-21.5, -9.93]    │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_dummy_L_contacts_e_row2_c… │ 0.22  │ [-21.0, -9.93]    │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_dummy_L_contacts_e_row2_c… │ 0.22  │ [-20.5, -9.93]    │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_dummy_L_contacts_e_row2_c… │ 0.22  │ [-20.0, -9.93]    │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_dummy_L_contacts_e_row2_c… │ 0.22  │ [-19.5, -9.93]    │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_contacts_b_contacts_E_row… │ 0.22  │ [-10.04, -9.62]   │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_contacts_b_contacts_W_row… │ 0.22  │ [-16.1, -9.62]    │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_contacts_c_contacts_E_row… │ 0.22  │ [-9.3, -9.62]     │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_contacts_c_contacts_W_row… │ 0.22  │ [-16.84, -9.62]   │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_dummy_L_contacts_b_contac… │ 0.22  │ [-18.72, -9.62]   │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_dummy_L_contacts_b_contac… │ 0.22  │ [-24.78, -9.62]   │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_dummy_L_contacts_c_contac… │ 0.22  │ [-17.98, -9.62]   │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_dummy_L_contacts_c_contac… │ 0.22  │ [-25.52, -9.62]   │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_contacts_e_row3_col0_W     │ 0.22  │ [-15.32, -9.43]   │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_contacts_e_row3_col1_W     │ 0.22  │ [-14.82, -9.43]   │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_contacts_e_row3_col2_W     │ 0.22  │ [-14.32, -9.43]   │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_contacts_e_row3_col3_W     │ 0.22  │ [-13.82, -9.43]   │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_contacts_e_row3_col4_W     │ 0.22  │ [-13.32, -9.43]   │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_contacts_e_row3_col5_W     │ 0.22  │ [-12.82, -9.43]   │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_contacts_e_row3_col6_W     │ 0.22  │ [-12.32, -9.43]   │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_contacts_e_row3_col7_W     │ 0.22  │ [-11.82, -9.43]   │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_contacts_e_row3_col8_W     │ 0.22  │ [-11.32, -9.43]   │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_contacts_e_row3_col9_W     │ 0.22  │ [-10.82, -9.43]   │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_dummy_L_contacts_e_row3_c… │ 0.22  │ [-24.0, -9.43]    │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_dummy_L_contacts_e_row3_c… │ 0.22  │ [-23.5, -9.43]    │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_dummy_L_contacts_e_row3_c… │ 0.22  │ [-23.0, -9.43]    │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_dummy_L_contacts_e_row3_c… │ 0.22  │ [-22.5, -9.43]    │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_dummy_L_contacts_e_row3_c… │ 0.22  │ [-22.0, -9.43]    │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_dummy_L_contacts_e_row3_c… │ 0.22  │ [-21.5, -9.43]    │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_dummy_L_contacts_e_row3_c… │ 0.22  │ [-21.0, -9.43]    │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_dummy_L_contacts_e_row3_c… │ 0.22  │ [-20.5, -9.43]    │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_dummy_L_contacts_e_row3_c… │ 0.22  │ [-20.0, -9.43]    │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_dummy_L_contacts_e_row3_c… │ 0.22  │ [-19.5, -9.43]    │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_contacts_b_contacts_E_row… │ 0.22  │ [-10.04, -9.15]   │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_contacts_b_contacts_W_row… │ 0.22  │ [-16.1, -9.15]    │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_contacts_c_contacts_E_row… │ 0.22  │ [-9.3, -9.15]     │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_contacts_c_contacts_W_row… │ 0.22  │ [-16.84, -9.15]   │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_dummy_L_contacts_b_contac… │ 0.22  │ [-18.72, -9.15]   │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_dummy_L_contacts_b_contac… │ 0.22  │ [-24.78, -9.15]   │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_dummy_L_contacts_c_contac… │ 0.22  │ [-17.98, -9.15]   │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_dummy_L_contacts_c_contac… │ 0.22  │ [-25.52, -9.15]   │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_contacts_e_row4_col0_W     │ 0.22  │ [-15.32, -8.93]   │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_contacts_e_row4_col1_W     │ 0.22  │ [-14.82, -8.93]   │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_contacts_e_row4_col2_W     │ 0.22  │ [-14.32, -8.93]   │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_contacts_e_row4_col3_W     │ 0.22  │ [-13.82, -8.93]   │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_contacts_e_row4_col4_W     │ 0.22  │ [-13.32, -8.93]   │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_contacts_e_row4_col5_W     │ 0.22  │ [-12.82, -8.93]   │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_contacts_e_row4_col6_W     │ 0.22  │ [-12.32, -8.93]   │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_contacts_e_row4_col7_W     │ 0.22  │ [-11.82, -8.93]   │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_contacts_e_row4_col8_W     │ 0.22  │ [-11.32, -8.93]   │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_contacts_e_row4_col9_W     │ 0.22  │ [-10.82, -8.93]   │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_dummy_L_contacts_e_row4_c… │ 0.22  │ [-24.0, -8.93]    │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_dummy_L_contacts_e_row4_c… │ 0.22  │ [-23.5, -8.93]    │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_dummy_L_contacts_e_row4_c… │ 0.22  │ [-23.0, -8.93]    │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_dummy_L_contacts_e_row4_c… │ 0.22  │ [-22.5, -8.93]    │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_dummy_L_contacts_e_row4_c… │ 0.22  │ [-22.0, -8.93]    │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_dummy_L_contacts_e_row4_c… │ 0.22  │ [-21.5, -8.93]    │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_dummy_L_contacts_e_row4_c… │ 0.22  │ [-21.0, -8.93]    │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_dummy_L_contacts_e_row4_c… │ 0.22  │ [-20.5, -8.93]    │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_dummy_L_contacts_e_row4_c… │ 0.22  │ [-20.0, -8.93]    │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_dummy_L_contacts_e_row4_c… │ 0.22  │ [-19.5, -8.93]    │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_diff_e_W                   │ 5.32  │ [-15.62, -8.68]   │ 180.0       │ [31, 0]  │ electrical │
# │ col_0_multiplier_0_tap_e_W                    │ 5.0   │ [-15.46, -8.68]   │ 180.0       │ [22, 0]  │ electrical │
# │ col_0_multiplier_0_well_W                     │ 6.8   │ [-16.36, -8.68]   │ 180.0       │ [21, 0]  │ electrical │
# │ col_0_multiplier_0_lvs_W                      │ 5.0   │ [-15.46, -8.68]   │ 180.0       │ [118, 5] │ electrical │
# │ col_0_multiplier_0_drc_W                      │ 8.28  │ [-17.1, -8.68]    │ 180.0       │ [127, 5] │ electrical │
# │ col_0_multiplier_0_E_W                        │ 5.0   │ [-15.46, -8.68]   │ 180.0       │ [34, 0]  │ electrical │
# │ col_0_multiplier_0_B_metal_E_W                │ 6.48  │ [-10.14, -8.68]   │ 180.0       │ [34, 0]  │ electrical │
# │ col_0_multiplier_0_B_metal_W_W                │ 6.48  │ [-16.2, -8.68]    │ 180.0       │ [34, 0]  │ electrical │
# │ col_0_multiplier_0_C_metal_E_W                │ 7.96  │ [-9.4, -8.68]     │ 180.0       │ [34, 0]  │ electrical │
# │ col_0_multiplier_0_C_metal_W_W                │ 7.96  │ [-16.94, -8.68]   │ 180.0       │ [34, 0]  │ electrical │
# │ col_0_multiplier_0_contacts_b_contacts_E_row… │ 0.22  │ [-10.04, -8.68]   │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_contacts_b_contacts_W_row… │ 0.22  │ [-16.1, -8.68]    │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_contacts_c_contacts_E_row… │ 0.22  │ [-9.3, -8.68]     │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_contacts_c_contacts_W_row… │ 0.22  │ [-16.84, -8.68]   │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_emitter_W                  │ 0.5   │ [-13.21, -8.68]   │ 180.0       │ [36, 0]  │ electrical │
# │ col_0_multiplier_0_dummy_L_diff_e_W           │ 5.32  │ [-24.3, -8.68]    │ 180.0       │ [31, 0]  │ electrical │
# │ col_0_multiplier_0_dummy_L_tap_e_W            │ 5.0   │ [-24.14, -8.68]   │ 180.0       │ [22, 0]  │ electrical │
# │ col_0_multiplier_0_dummy_L_well_W             │ 6.8   │ [-25.04, -8.68]   │ 180.0       │ [21, 0]  │ electrical │
# │ col_0_multiplier_0_dummy_L_lvs_W              │ 5.0   │ [-24.14, -8.68]   │ 180.0       │ [118, 5] │ electrical │
# │ col_0_multiplier_0_dummy_L_drc_W              │ 8.28  │ [-25.78, -8.68]   │ 180.0       │ [127, 5] │ electrical │
# │ col_0_multiplier_0_dummy_L_E_W                │ 5.0   │ [-24.14, -8.68]   │ 180.0       │ [34, 0]  │ electrical │
# │ col_0_multiplier_0_dummy_L_B_metal_E_W        │ 6.48  │ [-18.82, -8.68]   │ 180.0       │ [34, 0]  │ electrical │
# │ col_0_multiplier_0_dummy_L_B_metal_W_W        │ 6.48  │ [-24.88, -8.68]   │ 180.0       │ [34, 0]  │ electrical │
# │ col_0_multiplier_0_dummy_L_C_metal_E_W        │ 7.96  │ [-18.08, -8.68]   │ 180.0       │ [34, 0]  │ electrical │
# │ col_0_multiplier_0_dummy_L_C_metal_W_W        │ 7.96  │ [-25.62, -8.68]   │ 180.0       │ [34, 0]  │ electrical │
# │ col_0_multiplier_0_dummy_L_contacts_b_contac… │ 0.22  │ [-18.72, -8.68]   │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_dummy_L_contacts_b_contac… │ 0.22  │ [-24.78, -8.68]   │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_dummy_L_contacts_c_contac… │ 0.22  │ [-17.98, -8.68]   │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_dummy_L_contacts_c_contac… │ 0.22  │ [-25.52, -8.68]   │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_emitter_W                               │ 0.5   │ [-13.21, -8.68]   │ 180.0       │ [36, 0]  │ electrical │
# │ col_0_multiplier_0_contacts_e_row5_col0_W     │ 0.22  │ [-15.32, -8.43]   │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_contacts_e_row5_col1_W     │ 0.22  │ [-14.82, -8.43]   │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_contacts_e_row5_col2_W     │ 0.22  │ [-14.32, -8.43]   │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_contacts_e_row5_col3_W     │ 0.22  │ [-13.82, -8.43]   │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_contacts_e_row5_col4_W     │ 0.22  │ [-13.32, -8.43]   │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_contacts_e_row5_col5_W     │ 0.22  │ [-12.82, -8.43]   │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_contacts_e_row5_col6_W     │ 0.22  │ [-12.32, -8.43]   │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_contacts_e_row5_col7_W     │ 0.22  │ [-11.82, -8.43]   │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_contacts_e_row5_col8_W     │ 0.22  │ [-11.32, -8.43]   │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_contacts_e_row5_col9_W     │ 0.22  │ [-10.82, -8.43]   │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_dummy_L_contacts_e_row5_c… │ 0.22  │ [-24.0, -8.43]    │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_dummy_L_contacts_e_row5_c… │ 0.22  │ [-23.5, -8.43]    │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_dummy_L_contacts_e_row5_c… │ 0.22  │ [-23.0, -8.43]    │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_dummy_L_contacts_e_row5_c… │ 0.22  │ [-22.5, -8.43]    │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_dummy_L_contacts_e_row5_c… │ 0.22  │ [-22.0, -8.43]    │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_dummy_L_contacts_e_row5_c… │ 0.22  │ [-21.5, -8.43]    │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_dummy_L_contacts_e_row5_c… │ 0.22  │ [-21.0, -8.43]    │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_dummy_L_contacts_e_row5_c… │ 0.22  │ [-20.5, -8.43]    │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_dummy_L_contacts_e_row5_c… │ 0.22  │ [-20.0, -8.43]    │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_dummy_L_contacts_e_row5_c… │ 0.22  │ [-19.5, -8.43]    │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_contacts_b_contacts_E_row… │ 0.22  │ [-10.04, -8.21]   │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_contacts_b_contacts_W_row… │ 0.22  │ [-16.1, -8.21]    │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_contacts_c_contacts_E_row… │ 0.22  │ [-9.3, -8.21]     │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_contacts_c_contacts_W_row… │ 0.22  │ [-16.84, -8.21]   │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_dummy_L_contacts_b_contac… │ 0.22  │ [-18.72, -8.21]   │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_dummy_L_contacts_b_contac… │ 0.22  │ [-24.78, -8.21]   │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_dummy_L_contacts_c_contac… │ 0.22  │ [-17.98, -8.21]   │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_dummy_L_contacts_c_contac… │ 0.22  │ [-25.52, -8.21]   │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_contacts_e_row6_col0_W     │ 0.22  │ [-15.32, -7.93]   │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_contacts_e_row6_col1_W     │ 0.22  │ [-14.82, -7.93]   │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_contacts_e_row6_col2_W     │ 0.22  │ [-14.32, -7.93]   │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_contacts_e_row6_col3_W     │ 0.22  │ [-13.82, -7.93]   │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_contacts_e_row6_col4_W     │ 0.22  │ [-13.32, -7.93]   │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_contacts_e_row6_col5_W     │ 0.22  │ [-12.82, -7.93]   │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_contacts_e_row6_col6_W     │ 0.22  │ [-12.32, -7.93]   │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_contacts_e_row6_col7_W     │ 0.22  │ [-11.82, -7.93]   │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_contacts_e_row6_col8_W     │ 0.22  │ [-11.32, -7.93]   │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_contacts_e_row6_col9_W     │ 0.22  │ [-10.82, -7.93]   │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_dummy_L_contacts_e_row6_c… │ 0.22  │ [-24.0, -7.93]    │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_dummy_L_contacts_e_row6_c… │ 0.22  │ [-23.5, -7.93]    │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_dummy_L_contacts_e_row6_c… │ 0.22  │ [-23.0, -7.93]    │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_dummy_L_contacts_e_row6_c… │ 0.22  │ [-22.5, -7.93]    │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_dummy_L_contacts_e_row6_c… │ 0.22  │ [-22.0, -7.93]    │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_dummy_L_contacts_e_row6_c… │ 0.22  │ [-21.5, -7.93]    │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_dummy_L_contacts_e_row6_c… │ 0.22  │ [-21.0, -7.93]    │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_dummy_L_contacts_e_row6_c… │ 0.22  │ [-20.5, -7.93]    │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_dummy_L_contacts_e_row6_c… │ 0.22  │ [-20.0, -7.93]    │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_dummy_L_contacts_e_row6_c… │ 0.22  │ [-19.5, -7.93]    │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_contacts_b_contacts_E_row… │ 0.22  │ [-10.04, -7.74]   │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_contacts_b_contacts_W_row… │ 0.22  │ [-16.1, -7.74]    │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_contacts_c_contacts_E_row… │ 0.22  │ [-9.3, -7.74]     │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_contacts_c_contacts_W_row… │ 0.22  │ [-16.84, -7.74]   │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_dummy_L_contacts_b_contac… │ 0.22  │ [-18.72, -7.74]   │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_dummy_L_contacts_b_contac… │ 0.22  │ [-24.78, -7.74]   │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_dummy_L_contacts_c_contac… │ 0.22  │ [-17.98, -7.74]   │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_dummy_L_contacts_c_contac… │ 0.22  │ [-25.52, -7.74]   │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_contacts_e_row7_col0_W     │ 0.22  │ [-15.32, -7.43]   │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_contacts_e_row7_col1_W     │ 0.22  │ [-14.82, -7.43]   │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_contacts_e_row7_col2_W     │ 0.22  │ [-14.32, -7.43]   │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_contacts_e_row7_col3_W     │ 0.22  │ [-13.82, -7.43]   │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_contacts_e_row7_col4_W     │ 0.22  │ [-13.32, -7.43]   │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_contacts_e_row7_col5_W     │ 0.22  │ [-12.82, -7.43]   │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_contacts_e_row7_col6_W     │ 0.22  │ [-12.32, -7.43]   │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_contacts_e_row7_col7_W     │ 0.22  │ [-11.82, -7.43]   │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_contacts_e_row7_col8_W     │ 0.22  │ [-11.32, -7.43]   │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_contacts_e_row7_col9_W     │ 0.22  │ [-10.82, -7.43]   │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_dummy_L_contacts_e_row7_c… │ 0.22  │ [-24.0, -7.43]    │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_dummy_L_contacts_e_row7_c… │ 0.22  │ [-23.5, -7.43]    │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_dummy_L_contacts_e_row7_c… │ 0.22  │ [-23.0, -7.43]    │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_dummy_L_contacts_e_row7_c… │ 0.22  │ [-22.5, -7.43]    │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_dummy_L_contacts_e_row7_c… │ 0.22  │ [-22.0, -7.43]    │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_dummy_L_contacts_e_row7_c… │ 0.22  │ [-21.5, -7.43]    │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_dummy_L_contacts_e_row7_c… │ 0.22  │ [-21.0, -7.43]    │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_dummy_L_contacts_e_row7_c… │ 0.22  │ [-20.5, -7.43]    │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_dummy_L_contacts_e_row7_c… │ 0.22  │ [-20.0, -7.43]    │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_dummy_L_contacts_e_row7_c… │ 0.22  │ [-19.5, -7.43]    │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_contacts_b_contacts_E_row… │ 0.22  │ [-10.04, -7.27]   │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_contacts_b_contacts_W_row… │ 0.22  │ [-16.1, -7.27]    │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_contacts_c_contacts_E_row… │ 0.22  │ [-9.3, -7.27]     │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_contacts_c_contacts_W_row… │ 0.22  │ [-16.84, -7.27]   │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_dummy_L_contacts_b_contac… │ 0.22  │ [-18.72, -7.27]   │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_dummy_L_contacts_b_contac… │ 0.22  │ [-24.78, -7.27]   │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_dummy_L_contacts_c_contac… │ 0.22  │ [-17.98, -7.27]   │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_dummy_L_contacts_c_contac… │ 0.22  │ [-25.52, -7.27]   │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_contacts_e_row8_col0_W     │ 0.22  │ [-15.32, -6.93]   │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_contacts_e_row8_col1_W     │ 0.22  │ [-14.82, -6.93]   │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_contacts_e_row8_col2_W     │ 0.22  │ [-14.32, -6.93]   │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_contacts_e_row8_col3_W     │ 0.22  │ [-13.82, -6.93]   │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_contacts_e_row8_col4_W     │ 0.22  │ [-13.32, -6.93]   │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_contacts_e_row8_col5_W     │ 0.22  │ [-12.82, -6.93]   │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_contacts_e_row8_col6_W     │ 0.22  │ [-12.32, -6.93]   │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_contacts_e_row8_col7_W     │ 0.22  │ [-11.82, -6.93]   │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_contacts_e_row8_col8_W     │ 0.22  │ [-11.32, -6.93]   │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_contacts_e_row8_col9_W     │ 0.22  │ [-10.82, -6.93]   │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_dummy_L_contacts_e_row8_c… │ 0.22  │ [-24.0, -6.93]    │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_dummy_L_contacts_e_row8_c… │ 0.22  │ [-23.5, -6.93]    │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_dummy_L_contacts_e_row8_c… │ 0.22  │ [-23.0, -6.93]    │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_dummy_L_contacts_e_row8_c… │ 0.22  │ [-22.5, -6.93]    │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_dummy_L_contacts_e_row8_c… │ 0.22  │ [-22.0, -6.93]    │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_dummy_L_contacts_e_row8_c… │ 0.22  │ [-21.5, -6.93]    │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_dummy_L_contacts_e_row8_c… │ 0.22  │ [-21.0, -6.93]    │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_dummy_L_contacts_e_row8_c… │ 0.22  │ [-20.5, -6.93]    │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_dummy_L_contacts_e_row8_c… │ 0.22  │ [-20.0, -6.93]    │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_dummy_L_contacts_e_row8_c… │ 0.22  │ [-19.5, -6.93]    │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_contacts_b_contacts_E_row… │ 0.22  │ [-10.04, -6.8]    │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_contacts_b_contacts_W_row… │ 0.22  │ [-16.1, -6.8]     │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_contacts_c_contacts_E_row… │ 0.22  │ [-9.3, -6.8]      │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_contacts_c_contacts_W_row… │ 0.22  │ [-16.84, -6.8]    │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_dummy_L_contacts_b_contac… │ 0.22  │ [-18.72, -6.8]    │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_dummy_L_contacts_b_contac… │ 0.22  │ [-24.78, -6.8]    │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_dummy_L_contacts_c_contac… │ 0.22  │ [-17.98, -6.8]    │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_dummy_L_contacts_c_contac… │ 0.22  │ [-25.52, -6.8]    │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_contacts_e_row9_col0_W     │ 0.22  │ [-15.32, -6.43]   │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_contacts_e_row9_col1_W     │ 0.22  │ [-14.82, -6.43]   │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_contacts_e_row9_col2_W     │ 0.22  │ [-14.32, -6.43]   │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_contacts_e_row9_col3_W     │ 0.22  │ [-13.82, -6.43]   │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_contacts_e_row9_col4_W     │ 0.22  │ [-13.32, -6.43]   │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_contacts_e_row9_col5_W     │ 0.22  │ [-12.82, -6.43]   │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_contacts_e_row9_col6_W     │ 0.22  │ [-12.32, -6.43]   │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_contacts_e_row9_col7_W     │ 0.22  │ [-11.82, -6.43]   │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_contacts_e_row9_col8_W     │ 0.22  │ [-11.32, -6.43]   │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_contacts_e_row9_col9_W     │ 0.22  │ [-10.82, -6.43]   │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_dummy_L_contacts_e_row9_c… │ 0.22  │ [-24.0, -6.43]    │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_dummy_L_contacts_e_row9_c… │ 0.22  │ [-23.5, -6.43]    │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_dummy_L_contacts_e_row9_c… │ 0.22  │ [-23.0, -6.43]    │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_dummy_L_contacts_e_row9_c… │ 0.22  │ [-22.5, -6.43]    │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_dummy_L_contacts_e_row9_c… │ 0.22  │ [-22.0, -6.43]    │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_dummy_L_contacts_e_row9_c… │ 0.22  │ [-21.5, -6.43]    │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_dummy_L_contacts_e_row9_c… │ 0.22  │ [-21.0, -6.43]    │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_dummy_L_contacts_e_row9_c… │ 0.22  │ [-20.5, -6.43]    │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_dummy_L_contacts_e_row9_c… │ 0.22  │ [-20.0, -6.43]    │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_dummy_L_contacts_e_row9_c… │ 0.22  │ [-19.5, -6.43]    │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_contacts_b_contacts_E_row… │ 0.22  │ [-10.04, -6.33]   │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_contacts_b_contacts_W_row… │ 0.22  │ [-16.1, -6.33]    │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_contacts_c_contacts_E_row… │ 0.22  │ [-9.3, -6.33]     │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_contacts_c_contacts_W_row… │ 0.22  │ [-16.84, -6.33]   │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_dummy_L_contacts_b_contac… │ 0.22  │ [-18.72, -6.33]   │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_dummy_L_contacts_b_contac… │ 0.22  │ [-24.78, -6.33]   │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_dummy_L_contacts_c_contac… │ 0.22  │ [-17.98, -6.33]   │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_dummy_L_contacts_c_contac… │ 0.22  │ [-25.52, -6.33]   │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_contacts_b_contacts_E_row… │ 0.22  │ [-10.04, -5.86]   │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_contacts_b_contacts_W_row… │ 0.22  │ [-16.1, -5.86]    │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_contacts_c_contacts_E_row… │ 0.22  │ [-9.3, -5.86]     │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_contacts_c_contacts_W_row… │ 0.22  │ [-16.84, -5.86]   │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_dummy_L_contacts_b_contac… │ 0.22  │ [-18.72, -5.86]   │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_dummy_L_contacts_b_contac… │ 0.22  │ [-24.78, -5.86]   │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_dummy_L_contacts_c_contac… │ 0.22  │ [-17.98, -5.86]   │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_dummy_L_contacts_c_contac… │ 0.22  │ [-25.52, -5.86]   │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_base_W                     │ 0.5   │ [-16.98, -5.69]   │ 180.0       │ [36, 0]  │ electrical │
# │ col_0_base_W                                  │ 0.5   │ [-16.98, -5.69]   │ 180.0       │ [36, 0]  │ electrical │
# │ col_0_multiplier_0_B_metal_N_W                │ 0.42  │ [-16.2, -5.65]    │ 180.0       │ [34, 0]  │ electrical │
# │ col_0_multiplier_0_contacts_b_contacts_N_row… │ 0.22  │ [-15.42, -5.65]   │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_contacts_b_contacts_N_row… │ 0.22  │ [-14.95, -5.65]   │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_contacts_b_contacts_N_row… │ 0.22  │ [-14.48, -5.65]   │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_contacts_b_contacts_N_row… │ 0.22  │ [-14.01, -5.65]   │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_contacts_b_contacts_N_row… │ 0.22  │ [-13.54, -5.65]   │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_contacts_b_contacts_N_row… │ 0.22  │ [-13.07, -5.65]   │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_contacts_b_contacts_N_row… │ 0.22  │ [-12.6, -5.65]    │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_contacts_b_contacts_N_row… │ 0.22  │ [-12.13, -5.65]   │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_contacts_b_contacts_N_row… │ 0.22  │ [-11.66, -5.65]   │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_contacts_b_contacts_N_row… │ 0.22  │ [-11.19, -5.65]   │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_contacts_b_contacts_N_row… │ 0.22  │ [-10.72, -5.65]   │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_dummy_L_B_metal_N_W        │ 0.42  │ [-24.88, -5.65]   │ 180.0       │ [34, 0]  │ electrical │
# │ col_0_multiplier_0_dummy_L_contacts_b_contac… │ 0.22  │ [-24.1, -5.65]    │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_dummy_L_contacts_b_contac… │ 0.22  │ [-23.63, -5.65]   │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_dummy_L_contacts_b_contac… │ 0.22  │ [-23.16, -5.65]   │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_dummy_L_contacts_b_contac… │ 0.22  │ [-22.69, -5.65]   │ 180.0       │ [33, 0]  │ electrical │
# │ col_0_multiplier_0_dummy_L_contacts_b_contac… │ 0.22  │ [-22.22, -5.65]   │ 180.0       │ [33, 0]  │ electrical │
# ...
# │ col_2_multiplier_1_contacts_c_contacts_N_row… │ 0.22  │ [10.375, 3.66]    │ 270.0       │ [33, 0]  │ electrical │
# │ col_2_multiplier_1_contacts_c_contacts_S_row… │ 0.22  │ [10.375, -3.88]   │ 270.0       │ [33, 0]  │ electrical │
# │ col_2_multiplier_2_contacts_c_contacts_N_row… │ 0.22  │ [10.375, 12.34]   │ 270.0       │ [33, 0]  │ electrical │
# │ col_2_multiplier_2_contacts_c_contacts_S_row… │ 0.22  │ [10.375, 4.8]     │ 270.0       │ [33, 0]  │ electrical │
# │ col_2_multiplier_0_B_metal_W_S                │ 0.42  │ [9.93, -11.92]    │ 270.0       │ [34, 0]  │ electrical │
# │ col_2_multiplier_0_contacts_b_contacts_W_row… │ 0.22  │ [9.93, -11.61]    │ 270.0       │ [33, 0]  │ electrical │
# │ col_2_multiplier_0_contacts_b_contacts_W_row… │ 0.22  │ [9.93, -11.14]    │ 270.0       │ [33, 0]  │ electrical │
# │ col_2_multiplier_0_contacts_b_contacts_W_row… │ 0.22  │ [9.93, -10.67]    │ 270.0       │ [33, 0]  │ electrical │
# │ col_2_multiplier_0_contacts_b_contacts_W_row… │ 0.22  │ [9.93, -10.2]     │ 270.0       │ [33, 0]  │ electrical │
# │ col_2_multiplier_0_contacts_b_contacts_W_row… │ 0.22  │ [9.93, -9.73]     │ 270.0       │ [33, 0]  │ electrical │
# │ col_2_multiplier_0_contacts_b_contacts_W_row… │ 0.22  │ [9.93, -9.26]     │ 270.0       │ [33, 0]  │ electrical │
# │ col_2_multiplier_0_contacts_b_contacts_W_row… │ 0.22  │ [9.93, -8.79]     │ 270.0       │ [33, 0]  │ electrical │
# │ col_2_multiplier_0_contacts_b_contacts_W_row… │ 0.22  │ [9.93, -8.32]     │ 270.0       │ [33, 0]  │ electrical │
# │ col_2_multiplier_0_contacts_b_contacts_W_row… │ 0.22  │ [9.93, -7.85]     │ 270.0       │ [33, 0]  │ electrical │
# │ col_2_multiplier_0_contacts_b_contacts_W_row… │ 0.22  │ [9.93, -7.38]     │ 270.0       │ [33, 0]  │ electrical │
# │ col_2_multiplier_0_contacts_b_contacts_W_row… │ 0.22  │ [9.93, -6.91]     │ 270.0       │ [33, 0]  │ electrical │
# │ col_2_multiplier_0_contacts_b_contacts_W_row… │ 0.22  │ [9.93, -6.44]     │ 270.0       │ [33, 0]  │ electrical │
# │ col_2_multiplier_0_contacts_b_contacts_W_row… │ 0.22  │ [9.93, -5.97]     │ 270.0       │ [33, 0]  │ electrical │
# │ col_2_multiplier_1_B_metal_W_S                │ 0.42  │ [9.93, -3.24]     │ 270.0       │ [34, 0]  │ electrical │
# │ col_2_multiplier_1_contacts_b_contacts_W_row… │ 0.22  │ [9.93, -2.93]     │ 270.0       │ [33, 0]  │ electrical │
# │ col_2_multiplier_1_contacts_b_contacts_W_row… │ 0.22  │ [9.93, -2.46]     │ 270.0       │ [33, 0]  │ electrical │
# │ col_2_multiplier_1_contacts_b_contacts_W_row… │ 0.22  │ [9.93, -1.99]     │ 270.0       │ [33, 0]  │ electrical │
# │ col_2_multiplier_1_contacts_b_contacts_W_row… │ 0.22  │ [9.93, -1.52]     │ 270.0       │ [33, 0]  │ electrical │
# │ col_2_multiplier_1_contacts_b_contacts_W_row… │ 0.22  │ [9.93, -1.05]     │ 270.0       │ [33, 0]  │ electrical │
# │ col_2_multiplier_1_contacts_b_contacts_W_row… │ 0.22  │ [9.93, -0.58]     │ 270.0       │ [33, 0]  │ electrical │
# │ col_2_multiplier_1_contacts_b_contacts_W_row… │ 0.22  │ [9.93, -0.11]     │ 270.0       │ [33, 0]  │ electrical │
# │ col_2_multiplier_1_contacts_b_contacts_W_row… │ 0.22  │ [9.93, 0.36]      │ 270.0       │ [33, 0]  │ electrical │
# │ col_2_multiplier_1_contacts_b_contacts_W_row… │ 0.22  │ [9.93, 0.83]      │ 270.0       │ [33, 0]  │ electrical │
# │ col_2_multiplier_1_contacts_b_contacts_W_row… │ 0.22  │ [9.93, 1.3]       │ 270.0       │ [33, 0]  │ electrical │
# │ col_2_multiplier_1_contacts_b_contacts_W_row… │ 0.22  │ [9.93, 1.77]      │ 270.0       │ [33, 0]  │ electrical │
# │ col_2_multiplier_1_contacts_b_contacts_W_row… │ 0.22  │ [9.93, 2.24]      │ 270.0       │ [33, 0]  │ electrical │
# │ col_2_multiplier_1_contacts_b_contacts_W_row… │ 0.22  │ [9.93, 2.71]      │ 270.0       │ [33, 0]  │ electrical │
# │ col_2_multiplier_2_B_metal_W_S                │ 0.42  │ [9.93, 5.44]      │ 270.0       │ [34, 0]  │ electrical │
# │ col_2_multiplier_2_contacts_b_contacts_W_row… │ 0.22  │ [9.93, 5.75]      │ 270.0       │ [33, 0]  │ electrical │
# │ col_2_multiplier_2_contacts_b_contacts_W_row… │ 0.22  │ [9.93, 6.22]      │ 270.0       │ [33, 0]  │ electrical │
# │ col_2_multiplier_2_contacts_b_contacts_W_row… │ 0.22  │ [9.93, 6.69]      │ 270.0       │ [33, 0]  │ electrical │
# │ col_2_multiplier_2_contacts_b_contacts_W_row… │ 0.22  │ [9.93, 7.16]      │ 270.0       │ [33, 0]  │ electrical │
# │ col_2_multiplier_2_contacts_b_contacts_W_row… │ 0.22  │ [9.93, 7.63]      │ 270.0       │ [33, 0]  │ electrical │
# │ col_2_multiplier_2_contacts_b_contacts_W_row… │ 0.22  │ [9.93, 8.1]       │ 270.0       │ [33, 0]  │ electrical │
# │ col_2_multiplier_2_contacts_b_contacts_W_row… │ 0.22  │ [9.93, 8.57]      │ 270.0       │ [33, 0]  │ electrical │
# │ col_2_multiplier_2_contacts_b_contacts_W_row… │ 0.22  │ [9.93, 9.04]      │ 270.0       │ [33, 0]  │ electrical │
# │ col_2_multiplier_2_contacts_b_contacts_W_row… │ 0.22  │ [9.93, 9.51]      │ 270.0       │ [33, 0]  │ electrical │
# │ col_2_multiplier_2_contacts_b_contacts_W_row… │ 0.22  │ [9.93, 9.98]      │ 270.0       │ [33, 0]  │ electrical │
# │ col_2_multiplier_2_contacts_b_contacts_W_row… │ 0.22  │ [9.93, 10.45]     │ 270.0       │ [33, 0]  │ electrical │
# │ col_2_multiplier_2_contacts_b_contacts_W_row… │ 0.22  │ [9.93, 10.92]     │ 270.0       │ [33, 0]  │ electrical │
# │ col_2_multiplier_2_contacts_b_contacts_W_row… │ 0.22  │ [9.93, 11.39]     │ 270.0       │ [33, 0]  │ electrical │
# │ col_2_multiplier_0_contacts_c_contacts_N_row… │ 0.22  │ [9.905, -5.02]    │ 270.0       │ [33, 0]  │ electrical │
# │ col_2_multiplier_0_contacts_c_contacts_S_row… │ 0.22  │ [9.905, -12.56]   │ 270.0       │ [33, 0]  │ electrical │
# │ col_2_multiplier_1_contacts_c_contacts_N_row… │ 0.22  │ [9.905, 3.66]     │ 270.0       │ [33, 0]  │ electrical │
# │ col_2_multiplier_1_contacts_c_contacts_S_row… │ 0.22  │ [9.905, -3.88]    │ 270.0       │ [33, 0]  │ electrical │
# │ col_2_multiplier_2_contacts_c_contacts_N_row… │ 0.22  │ [9.905, 12.34]    │ 270.0       │ [33, 0]  │ electrical │
# │ col_2_multiplier_2_contacts_c_contacts_S_row… │ 0.22  │ [9.905, 4.8]      │ 270.0       │ [33, 0]  │ electrical │
# │ col_2_multiplier_0_base_S                     │ 1.24  │ [9.56, -5.94]     │ 270.0       │ [36, 0]  │ electrical │
# │ col_2_multiplier_0_collector_S                │ 1.24  │ [9.56, -12.66]    │ 270.0       │ [36, 0]  │ electrical │
# │ col_2_multiplier_1_base_S                     │ 1.24  │ [9.56, 2.74]      │ 270.0       │ [36, 0]  │ electrical │
# │ col_2_multiplier_1_collector_S                │ 1.24  │ [9.56, -3.98]     │ 270.0       │ [36, 0]  │ electrical │
# │ col_2_multiplier_2_base_S                     │ 1.24  │ [9.56, 11.42]     │ 270.0       │ [36, 0]  │ electrical │
# │ col_2_multiplier_2_collector_S                │ 1.24  │ [9.56, 4.7]       │ 270.0       │ [36, 0]  │ electrical │
# │ col_2_base_S                                  │ 1.24  │ [9.56, -5.94]     │ 270.0       │ [36, 0]  │ electrical │
# │ col_2_collector_S                             │ 1.24  │ [9.56, -12.66]    │ 270.0       │ [36, 0]  │ electrical │
# │ col_2_multiplier_0_C_metal_W_S                │ 0.42  │ [9.19, -12.66]    │ 270.0       │ [34, 0]  │ electrical │
# │ col_2_multiplier_0_contacts_c_contacts_W_row… │ 0.22  │ [9.19, -12.55]    │ 270.0       │ [33, 0]  │ electrical │
# │ col_2_multiplier_0_contacts_c_contacts_W_row… │ 0.22  │ [9.19, -12.08]    │ 270.0       │ [33, 0]  │ electrical │
# │ col_2_multiplier_0_contacts_c_contacts_W_row… │ 0.22  │ [9.19, -11.61]    │ 270.0       │ [33, 0]  │ electrical │
# │ col_2_multiplier_0_contacts_c_contacts_W_row… │ 0.22  │ [9.19, -11.14]    │ 270.0       │ [33, 0]  │ electrical │
# │ col_2_multiplier_0_contacts_c_contacts_W_row… │ 0.22  │ [9.19, -10.67]    │ 270.0       │ [33, 0]  │ electrical │
# │ col_2_multiplier_0_contacts_c_contacts_W_row… │ 0.22  │ [9.19, -10.2]     │ 270.0       │ [33, 0]  │ electrical │
# │ col_2_multiplier_0_contacts_c_contacts_W_row… │ 0.22  │ [9.19, -9.73]     │ 270.0       │ [33, 0]  │ electrical │
# │ col_2_multiplier_0_contacts_c_contacts_W_row… │ 0.22  │ [9.19, -9.26]     │ 270.0       │ [33, 0]  │ electrical │
# │ col_2_multiplier_0_contacts_c_contacts_W_row… │ 0.22  │ [9.19, -8.79]     │ 270.0       │ [33, 0]  │ electrical │
# │ col_2_multiplier_0_contacts_c_contacts_W_row… │ 0.22  │ [9.19, -8.32]     │ 270.0       │ [33, 0]  │ electrical │
# │ col_2_multiplier_0_contacts_c_contacts_W_row… │ 0.22  │ [9.19, -7.85]     │ 270.0       │ [33, 0]  │ electrical │
# │ col_2_multiplier_0_contacts_c_contacts_W_row… │ 0.22  │ [9.19, -7.38]     │ 270.0       │ [33, 0]  │ electrical │
# │ col_2_multiplier_0_contacts_c_contacts_W_row… │ 0.22  │ [9.19, -6.91]     │ 270.0       │ [33, 0]  │ electrical │
# │ col_2_multiplier_0_contacts_c_contacts_W_row… │ 0.22  │ [9.19, -6.44]     │ 270.0       │ [33, 0]  │ electrical │
# │ col_2_multiplier_0_contacts_c_contacts_W_row… │ 0.22  │ [9.19, -5.97]     │ 270.0       │ [33, 0]  │ electrical │
# │ col_2_multiplier_0_contacts_c_contacts_W_row… │ 0.22  │ [9.19, -5.5]      │ 270.0       │ [33, 0]  │ electrical │
# │ col_2_multiplier_0_contacts_c_contacts_W_row… │ 0.22  │ [9.19, -5.03]     │ 270.0       │ [33, 0]  │ electrical │
# │ col_2_multiplier_1_C_metal_W_S                │ 0.42  │ [9.19, -3.98]     │ 270.0       │ [34, 0]  │ electrical │
# │ col_2_multiplier_1_contacts_c_contacts_W_row… │ 0.22  │ [9.19, -3.87]     │ 270.0       │ [33, 0]  │ electrical │
# │ col_2_multiplier_1_contacts_c_contacts_W_row… │ 0.22  │ [9.19, -3.4]      │ 270.0       │ [33, 0]  │ electrical │
# │ col_2_multiplier_1_contacts_c_contacts_W_row… │ 0.22  │ [9.19, -2.93]     │ 270.0       │ [33, 0]  │ electrical │
# │ col_2_multiplier_1_contacts_c_contacts_W_row… │ 0.22  │ [9.19, -2.46]     │ 270.0       │ [33, 0]  │ electrical │
# │ col_2_multiplier_1_contacts_c_contacts_W_row… │ 0.22  │ [9.19, -1.99]     │ 270.0       │ [33, 0]  │ electrical │
# │ col_2_multiplier_1_contacts_c_contacts_W_row… │ 0.22  │ [9.19, -1.52]     │ 270.0       │ [33, 0]  │ electrical │
# │ col_2_multiplier_1_contacts_c_contacts_W_row… │ 0.22  │ [9.19, -1.05]     │ 270.0       │ [33, 0]  │ electrical │
# │ col_2_multiplier_1_contacts_c_contacts_W_row… │ 0.22  │ [9.19, -0.58]     │ 270.0       │ [33, 0]  │ electrical │
# │ col_2_multiplier_1_contacts_c_contacts_W_row… │ 0.22  │ [9.19, -0.11]     │ 270.0       │ [33, 0]  │ electrical │
# │ col_2_multiplier_1_contacts_c_contacts_W_row… │ 0.22  │ [9.19, 0.36]      │ 270.0       │ [33, 0]  │ electrical │
# │ col_2_multiplier_1_contacts_c_contacts_W_row… │ 0.22  │ [9.19, 0.83]      │ 270.0       │ [33, 0]  │ electrical │
# │ col_2_multiplier_1_contacts_c_contacts_W_row… │ 0.22  │ [9.19, 1.3]       │ 270.0       │ [33, 0]  │ electrical │
# │ col_2_multiplier_1_contacts_c_contacts_W_row… │ 0.22  │ [9.19, 1.77]      │ 270.0       │ [33, 0]  │ electrical │
# │ col_2_multiplier_1_contacts_c_contacts_W_row… │ 0.22  │ [9.19, 2.24]      │ 270.0       │ [33, 0]  │ electrical │
# │ col_2_multiplier_1_contacts_c_contacts_W_row… │ 0.22  │ [9.19, 2.71]      │ 270.0       │ [33, 0]  │ electrical │
# │ col_2_multiplier_1_contacts_c_contacts_W_row… │ 0.22  │ [9.19, 3.18]      │ 270.0       │ [33, 0]  │ electrical │
# │ col_2_multiplier_1_contacts_c_contacts_W_row… │ 0.22  │ [9.19, 3.65]      │ 270.0       │ [33, 0]  │ electrical │
# │ col_2_multiplier_2_C_metal_W_S                │ 0.42  │ [9.19, 4.7]       │ 270.0       │ [34, 0]  │ electrical │
# │ col_2_multiplier_2_contacts_c_contacts_W_row… │ 0.22  │ [9.19, 4.81]      │ 270.0       │ [33, 0]  │ electrical │
# │ col_2_multiplier_2_contacts_c_contacts_W_row… │ 0.22  │ [9.19, 5.28]      │ 270.0       │ [33, 0]  │ electrical │
# │ col_2_multiplier_2_contacts_c_contacts_W_row… │ 0.22  │ [9.19, 5.75]      │ 270.0       │ [33, 0]  │ electrical │
# │ col_2_multiplier_2_contacts_c_contacts_W_row… │ 0.22  │ [9.19, 6.22]      │ 270.0       │ [33, 0]  │ electrical │
# │ col_2_multiplier_2_contacts_c_contacts_W_row… │ 0.22  │ [9.19, 6.69]      │ 270.0       │ [33, 0]  │ electrical │
# │ col_2_multiplier_2_contacts_c_contacts_W_row… │ 0.22  │ [9.19, 7.16]      │ 270.0       │ [33, 0]  │ electrical │
# │ col_2_multiplier_2_contacts_c_contacts_W_row… │ 0.22  │ [9.19, 7.63]      │ 270.0       │ [33, 0]  │ electrical │
# │ col_2_multiplier_2_contacts_c_contacts_W_row… │ 0.22  │ [9.19, 8.1]       │ 270.0       │ [33, 0]  │ electrical │
# │ col_2_multiplier_2_contacts_c_contacts_W_row… │ 0.22  │ [9.19, 8.57]      │ 270.0       │ [33, 0]  │ electrical │
# │ col_2_multiplier_2_contacts_c_contacts_W_row… │ 0.22  │ [9.19, 9.04]      │ 270.0       │ [33, 0]  │ electrical │
# │ col_2_multiplier_2_contacts_c_contacts_W_row… │ 0.22  │ [9.19, 9.51]      │ 270.0       │ [33, 0]  │ electrical │
# │ col_2_multiplier_2_contacts_c_contacts_W_row… │ 0.22  │ [9.19, 9.98]      │ 270.0       │ [33, 0]  │ electrical │
# │ col_2_multiplier_2_contacts_c_contacts_W_row… │ 0.22  │ [9.19, 10.45]     │ 270.0       │ [33, 0]  │ electrical │
# │ col_2_multiplier_2_contacts_c_contacts_W_row… │ 0.22  │ [9.19, 10.92]     │ 270.0       │ [33, 0]  │ electrical │
# │ col_2_multiplier_2_contacts_c_contacts_W_row… │ 0.22  │ [9.19, 11.39]     │ 270.0       │ [33, 0]  │ electrical │
# │ col_2_multiplier_2_contacts_c_contacts_W_row… │ 0.22  │ [9.19, 11.86]     │ 270.0       │ [33, 0]  │ electrical │
# │ col_2_multiplier_2_contacts_c_contacts_W_row… │ 0.22  │ [9.19, 12.33]     │ 270.0       │ [33, 0]  │ electrical │
# │ col_2_A_base_S                                │ 0.5   │ [8.09, -12.82]    │ 270.0       │ [42, 0]  │ electrical │
# │ col_2_A_collector_S                           │ 0.5   │ [6.99, -12.82]    │ 270.0       │ [42, 0]  │ electrical │
# │ col_2_B_base_S                                │ 0.5   │ [5.89, -12.82]    │ 270.0       │ [42, 0]  │ electrical │
# │ col_2_B_collector_S                           │ 0.5   │ [4.79, -12.82]    │ 270.0       │ [42, 0]  │ electrical │
# │ route_A_0_collectorcon_W                      │ 0.5   │ [-19.18, -13.07]  │ 180.0       │ [46, 0]  │ electrical │
# │ route_A_0_collectorcon_E                      │ 0.5   │ [-7.92, -13.07]   │ 0.0         │ [46, 0]  │ electrical │
# │ route_A_0_basecon_W                           │ 0.5   │ [-18.08, -14.17]  │ 180.0       │ [46, 0]  │ electrical │
# │ route_A_0_basecon_E                           │ 0.5   │ [-6.82, -14.17]   │ 0.0         │ [46, 0]  │ electrical │
# │ route_A_0_emittercon_W                        │ 0.5   │ [-12.11, 13.07]   │ 180.0       │ [46, 0]  │ electrical │
# │ route_A_0_emittercon_E                        │ 0.5   │ [2.45, 13.07]     │ 0.0         │ [46, 0]  │ electrical │
# │ route_A_1_collectorcon_W                      │ 0.5   │ [-8.42, -13.07]   │ 180.0       │ [46, 0]  │ electrical │
# │ route_A_1_collectorcon_E                      │ 0.5   │ [7.24, -13.07]    │ 0.0         │ [46, 0]  │ electrical │
# │ route_A_1_basecon_W                           │ 0.5   │ [-7.32, -14.17]   │ 180.0       │ [46, 0]  │ electrical │
# │ route_A_1_basecon_E                           │ 0.5   │ [8.34, -14.17]    │ 0.0         │ [46, 0]  │ electrical │
# │ route_A_1_emittercon_W                        │ 0.5   │ [1.95, 13.07]     │ 180.0       │ [46, 0]  │ electrical │
# │ route_A_1_emittercon_E                        │ 0.5   │ [14.31, 13.07]    │ 0.0         │ [46, 0]  │ electrical │
# │ route_B_0_collectorcon_W                      │ 0.5   │ [-21.38, -15.27]  │ 180.0       │ [46, 0]  │ electrical │
# │ route_B_0_collectorcon_E                      │ 0.5   │ [5.04, -15.27]    │ 0.0         │ [46, 0]  │ electrical │
# │ route_B_0_basecon_W                           │ 0.5   │ [-20.28, -16.37]  │ 180.0       │ [46, 0]  │ electrical │
# │ route_B_0_basecon_E                           │ 0.5   │ [6.14, -16.37]    │ 0.0         │ [46, 0]  │ electrical │
# │ route_B_0_emittercon_W                        │ 0.5   │ [-11.01, 14.17]   │ 180.0       │ [46, 0]  │ electrical │
# │ route_B_0_emittercon_E                        │ 0.5   │ [15.41, 14.17]    │ 0.0         │ [46, 0]  │ electrical │
# └───────────────────────────────────────────────┴───────┴───────────────────┴─────────────┴──────────┴────────────┘

# %%
from glayout.primitives.bjt import pnp, npn

# %%
from glayout.util.pattern import check_pattern_level, transpose_pattern

# %%
pattern =[ ["D", "E", "D", "D"],
["D", "D", "C", "D"],
["D", "B", "A",	"D"],
["D", "A", "B",	"D"],
["D", "C", "D",	"D"],
["D", "D", "E",	"D"]]

# %%
bjt_pnp=pnp(pdk=pdk,active_area=(5,5),bc_rmult=1,
                       multipliers=(6,4),
                       pattern=transpose_pattern(pattern),is_bc_shared=True)
# Out:
# {'D': [0, 1, 2, 3, 4, 5], 'B': [2, 3], 'A': [2, 3], 'E': [0, 5], 'C': [1, 4]}
# col_0_base_S
# col_0_base_S
# 1.1
# 0 D
# col_0_D_emitter_N
# col_1_D_emitter_N
# col_1_D_emitter_N
# col_2_D_emitter_N
# col_2_D_emitter_N
# col_3_D_emitter_N
# col_3_D_emitter_N
# col_4_D_emitter_N
# col_4_D_emitter_N
# col_5_D_emitter_N
# 1 B
# col_2_B_emitter_N
# col_3_B_emitter_N
# 2 A
# col_2_A_emitter_N
# col_3_A_emitter_N
# 3 E
# col_0_E_emitter_N
# col_5_E_emitter_N
# 4 C
# col_1_C_emitter_N
# col_4_C_emitter_N

# %%
bjt_pnp.show()
# Out:
# /headless/conda-env/miniconda3/envs/GLdev/lib/python3.10/site-packages/gdsfactory/show.py:40: UserWarning: Unnamed cells, 1 in 'Unnamed_943e96c1'
#   gdspath = component.write_gds(
# 2025-09-08 06:27:14.347 | INFO     | gdsfactory.klive:show:55 - Message from klive: {"version": "0.3.3", "klayout_version": "0.30.2", "type": "open", "file": "/tmp/gdsfactory/Unnamed_943e96c1.gds"}

# %% [markdown]
# The next code is specific for the AutoMOS project. In case of reuse, make sure the path is pointing to the right folder

# %%
from pathlib import Path
import os

# %%
designs_path=Path("/foss/designs")
library = designs_path / "libs" / "core_bandgap"
cell_name = "bandgap_bjt"
cell_path = library / cell_name

try:
    os.makedirs(cell_path, exist_ok=True)
    print(f"Directory '{cell_path}' ensured to exist.")
except OSError as e:
    print(f"Error creating directory '{cell_path}': {e}")
# Out:
# Directory '/foss/designs/libs/core_bandgap/bandgap_bjt' ensured to exist.

# %%
bjt_pnp.write_gds(cell_path / "bandgap_bjt.gds")
# Out:
# /tmp/ipykernel_804/2114480808.py:1: UserWarning: Unnamed cells, 1 in 'Unnamed_03d8da65'
#   bjt_pnp.write_gds(cell_path / "bandgap_bjt.gds")
# 2025-09-05 05:36:57.633 | INFO     | gdsfactory.component:_write_library:1851 - Wrote to '/foss/designs/libs/core_bandgap/bandgap_bjt/bandgap_bjt.gds'
# PosixPath('/foss/designs/libs/core_bandgap/bandgap_bjt/bandgap_bjt.gds')
